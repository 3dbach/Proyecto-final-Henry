# %%
import warnings

# Suprimir todos los warnings
warnings.filterwarnings('ignore')

# Ahora puedes ejecutar tu código sin que aparezcan mensajes de advertencia

warnings.filterwarnings('ignore', category=UserWarning)

# %%
import pandas as pd
import numpy as np

# %%
# Configura pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
ruta = '/content/drive/MyDrive/taxis_clean/'

# %%
septiembre = pd.read_parquet(ruta+'taxi_filtrado9.snappy.parquet')
agosto = pd.read_parquet(ruta+'taxi_filtrado8.snappy.parquet')
julio = pd.read_parquet(ruta+'taxi_filtrado7.snappy.parquet')
junio = pd.read_parquet(ruta+'taxi_filtrado6.snappy.parquet')
mayo = pd.read_parquet(ruta+'taxi_filtrado5.snappy.parquet')
abril = pd.read_parquet(ruta+'taxi_filtrado4.snappy.parquet')
marzo = pd.read_parquet(ruta+'taxi_filtrado3.snappy.parquet')
febrero= pd.read_parquet(ruta+'taxi_filtrado2.snappy.parquet')
enero= pd.read_parquet(ruta+'taxi_filtrado1.snappy.parquet')
taxis_zones = pd.read_csv('/content/drive/MyDrive/taxis_clean/taxi_zones.csv')

# %%
taxis_zones = pd.read_csv('/content/drive/MyDrive/taxis_clean/taxi_zones.csv')

# %%
taxis_zones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    263 non-null    int64
#  1   Shape_Leng  263 non-null    float64
#  2   Shape_Area  263 non-null    float64
#  3   zone        263 non-null    object
#  4   LocationID  263 non-null    int64
#  5   borough     263 non-null    object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 12.5+ KB

# %%
taxis_zones.head()
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough
# 0            EWR
# 1         Queens
# 2          Bronx
# 3      Manhattan
# 4  Staten Island

# %%
septiembre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2438018 entries, 0 to 2846721
# Data columns (total 20 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   vendorid               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   ratecodeid             float64
#  6   store_and_fwd_flag     object
#  7   pulocationid           int32
#  8   dolocationid           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
#  19  duracion               float64
# ...

# %%
#viajes_taxis = pd.concat([septiembre,agosto, julio, junio, mayo, abril, marzo, febrero, enero])

# %%
#viajes_taxis.info()

# %%
#viajes_taxis.columns

# %%
#viajes_taxis.head()

# %% [markdown]
# vendorid: Identificación del proveedor del servicio de taxi.
#
#
# tpep_pickup_datetime: Fecha y hora de recogida del taxi.
#
#
# tpep_dropoff_datetime: Fecha y hora de entrega del taxi.
#
#
# passenger_count: Número de pasajeros en el taxi.
#
#
# trip_distance: Distancia total del viaje en millas.
#
#
# ratecodeid: Código de tarifa utilizado para el viaje.
#
#
# store_and_fwd_flag: Indicador de si el registro fue almacenado y enviado posteriormente.
#
#
# pulocationid: ID de la ubicación de recogida.
#
#
# dolocationid: ID de la ubicación de entrega.
#
#
# payment_type: Método de pago utilizado.
#
#
# fare_amount: Tarifa básica del viaje.
#
#
# extra: Cargo adicional aplicado al viaje.
#
#
# mta_tax: Impuesto de la Autoridad Metropolitana de Transporte.
#
#
# tip_amount: Cantidad de propina dada en el viaje.
#
#
# tolls_amount: Cantidad de peajes cobrados en el viaje.
#
#
# improvement_surcharge: Mejora de la tarifa aplicada.
#
#
# total_amount: Monto total pagado por el viaje.
#
#
# congestion_surcharge: Recargo por congestión aplicado.
#
#
# airport_fee: Tarifa adicional por viaje al aeropuerto.
#
#
# duracion: Duración total del viaje en minutos.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el DataFrame
# Asegúrate de tener 'viajes_taxis' cargado con los datos relevantes

# Crear características temporales
#viajes_taxis['hora_del_dia'] = viajes_taxis['tpep_pickup_datetime'].dt.hour
#viajes_taxis['dia_de_la_semana'] = viajes_taxis['tpep_pickup_datetime'].dt.dayofweek

# %% [markdown]
# 3. Análisis de Relación entre Tarifa y Distancia:
# Objetivo:
# Analizar y predecir la relación entre la tarifa y la distancia del viaje.
#
# Pasos:
#
# Exploración de Datos:
#
# Explorar la relación entre la tarifa y la distancia mediante visualizaciones y estadísticas descriptivas.
# Modelo de Regresión:
#
# Utilizar un modelo de regresión para predecir la tarifa en función de la distancia y otras características relevantes.
# Evaluación del Modelo:
#
# Evaluar el rendimiento del modelo utilizando métricas como el error cuadrático medio.
# Visualización de Predicciones:
#
# Visualizar las predicciones del modelo junto con la relación real entre la tarifa y la distancia.

# %% [markdown]
# Index(['vendorid', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'ratecodeid', 'store_and_fwd_flag',
#        'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee', 'duracion',
#        'cluster', 'hora_del_dia', 'dia_de_la_semana'],
#       dtype='object')

# %%
#import pandas as pd

# Supongamos que 'viajes_taxis' es tu DataFrame actual
# Asegúrate de tener cargado tu DataFrame antes de ejecutar esta operación

# Seleccionar una muestra aleatoria de 500,000 datos
#muestra_aleatoria = viajes_taxis.sample(n=6_000_000, random_state=42)

# Ahora, 'muestra_aleatoria' contiene la muestra aleatoria que necesitas

# %%
#viajes_taxis.info()

# %%
#viajes_taxis.head()

# %%
#viajes_taxis.columns

# %%
import pandas as pd

# Cargar el conjunto de datos de taxi_zones
taxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")

septiembre['hora_del_dia'] = septiembre['tpep_pickup_datetime'].dt.hour
septiembre['dia_de_la_semana'] = septiembre['tpep_pickup_datetime'].dt.dayofweek


# Fusión con la columna 'pulocationid'
septiembre = pd.merge(septiembre, taxi_zones[['LocationID', 'borough', 'zone']], left_on='pulocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
septiembre = septiembre.rename(columns={'borough': 'pickup_borough', 'zone': 'pickup_zone'})

# Eliminar la columna redundante
septiembre = septiembre.drop('LocationID', axis=1)

# Fusión con la columna 'dolocationid'
septiembre = pd.merge(septiembre, taxi_zones[['LocationID', 'borough', 'zone']], left_on='dolocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
septiembre = septiembre.rename(columns={'borough': 'dropoff_borough', 'zone': 'dropoff_zone'})

# Eliminar la columna redundante
septiembre = septiembre.drop('LocationID', axis=1)

septiembre.to_parquet('septiembre.parquet')

# %%
septiembre.head()
# Out:
#    vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-09-01 00:15:37   2023-09-01 00:20:21              1.0
# 1         2  2023-09-01 00:18:40   2023-09-01 00:30:28              2.0
# 2         2  2023-09-01 00:35:01   2023-09-01 00:39:04              1.0
# 3         2  2023-09-01 00:45:45   2023-09-01 00:47:37              1.0
# 4         1  2023-09-01 00:01:04   2023-09-01 00:18:36              1.0
#
#    trip_distance  ratecodeid store_and_fwd_flag  pulocationid  dolocationid  \
# 0           0.80         1.0                  N           163           230
# 1           2.34         1.0                  N           236           233
# 2           1.62         1.0                  N           162           236
# 3           0.74         1.0                  N           141           229
# 4           3.90         1.0                  N           140             7
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
import pandas as pd

# Cargar el conjunto de datos de taxi_zones
taxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")

enero['hora_del_dia'] = enero['tpep_pickup_datetime'].dt.hour
enero['dia_de_la_semana'] = enero['tpep_pickup_datetime'].dt.dayofweek

# Fusión con la columna 'pulocationid'
enero = pd.merge(enero, taxi_zones[['LocationID', 'borough', 'zone']], left_on='pulocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
enero  = enero.rename(columns={'borough': 'pickup_borough', 'zone': 'pickup_zone'})

# Eliminar la columna redundante
enero  = enero.drop('LocationID', axis=1)

# Fusión con la columna 'dolocationid'
enero  = pd.merge(enero, taxi_zones[['LocationID', 'borough', 'zone']], left_on='dolocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
enero  = enero.rename(columns={'borough': 'dropoff_borough', 'zone': 'dropoff_zone'})

# Eliminar la columna redundante
enero = enero.drop('LocationID', axis=1)
enero.to_parquet('enero.parquet')

# %%
import pandas as pd

# Cargar el conjunto de datos de taxi_zones
taxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")

febrero['hora_del_dia'] = febrero['tpep_pickup_datetime'].dt.hour
febrero['dia_de_la_semana'] = febrero['tpep_pickup_datetime'].dt.dayofweek

# Fusión con la columna 'pulocationid'
febrero = pd.merge(febrero, taxi_zones[['LocationID', 'borough', 'zone']], left_on='pulocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
febrero  = febrero.rename(columns={'borough': 'pickup_borough', 'zone': 'pickup_zone'})

# Eliminar la columna redundante
febrero  = febrero.drop('LocationID', axis=1)

# Fusión con la columna 'dolocationid'
febrero  = pd.merge(febrero, taxi_zones[['LocationID', 'borough', 'zone']], left_on='dolocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
febrero  = febrero.rename(columns={'borough': 'dropoff_borough', 'zone': 'dropoff_zone'})

# Eliminar la columna redundante
febrero = febrero.drop('LocationID', axis=1)
febrero.to_parquet('febrero.parquet')

# %%
febrero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2529879 entries, 0 to 2529878
# Data columns (total 26 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   vendorid               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   ratecodeid             float64
#  6   store_and_fwd_flag     object
#  7   pulocationid           int32
#  8   dolocationid           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
#  19  duracion               float64
#  20  hora_del_dia           int64
# ...

# %%
febrero.head(10)
# Out:
#    vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
# 1         2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 2         2  2023-02-01 00:12:28   2023-02-01 00:25:46              1.0
# 3         1  2023-02-01 00:52:40   2023-02-01 01:07:18              1.0
# 4         1  2023-02-01 00:56:53   2023-02-01 01:00:37              1.0
# 5         2  2023-02-01 00:33:51   2023-02-01 00:37:34              1.0
# 6         2  2023-02-01 01:00:45   2023-02-01 01:06:00              1.0
# 7         2  2023-02-01 00:10:48   2023-02-01 00:18:09              1.0
# 8         2  2023-02-01 00:00:28   2023-02-01 00:12:54              1.0
# 9         2  2023-02-01 00:35:06   2023-02-01 00:45:47              1.0
#
#    trip_distance  ratecodeid store_and_fwd_flag  pulocationid  dolocationid  \
# 0           0.30         1.0                  N           142           163
# ...

# %%
import pandas as pd

# Cargar el conjunto de datos de taxi_zones
taxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")

marzo['hora_del_dia'] = marzo['tpep_pickup_datetime'].dt.hour
marzo['dia_de_la_semana'] = marzo['tpep_pickup_datetime'].dt.dayofweek


# Fusión con la columna 'pulocationid'
marzo = pd.merge(marzo, taxi_zones[['LocationID', 'borough', 'zone']], left_on='pulocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
marzo  = marzo.rename(columns={'borough': 'pickup_borough', 'zone': 'pickup_zone'})

# Eliminar la columna redundante
marzo  = marzo.drop('LocationID', axis=1)

# Fusión con la columna 'dolocationid'
marzo  = pd.merge(marzo, taxi_zones[['LocationID', 'borough', 'zone']], left_on='dolocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
marzo  = marzo.rename(columns={'borough': 'dropoff_borough', 'zone': 'dropoff_zone'})

# Eliminar la columna redundante
marzo = marzo.drop('LocationID', axis=1)
marzo.to_parquet('marzo.parquet')

# %%
import pandas as pd

# Cargar el conjunto de datos de taxi_zones
taxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")

abril['hora_del_dia'] = abril['tpep_pickup_datetime'].dt.hour
abril['dia_de_la_semana'] = abril['tpep_pickup_datetime'].dt.dayofweek


# Fusión con la columna 'pulocationid'
abril = pd.merge(abril , taxi_zones[['LocationID', 'borough', 'zone']], left_on='pulocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
abril  = abril.rename(columns={'borough': 'pickup_borough', 'zone': 'pickup_zone'})

# Eliminar la columna redundante
abril  = abril.drop('LocationID', axis=1)

# Fusión con la columna 'dolocationid'
abril  = pd.merge(abril, taxi_zones[['LocationID', 'borough', 'zone']], left_on='dolocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
abril  = abril.rename(columns={'borough': 'dropoff_borough', 'zone': 'dropoff_zone'})

# Eliminar la columna redundante
abril = abril.drop('LocationID', axis=1)
abril.to_parquet('abril.parquet')

# %%
import pandas as pd

# Cargar el conjunto de datos de taxi_zones
taxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")

mayo['hora_del_dia'] = mayo['tpep_pickup_datetime'].dt.hour
mayo['dia_de_la_semana'] = mayo['tpep_pickup_datetime'].dt.dayofweek


# Fusión con la columna 'pulocationid'
mayo = pd.merge(mayo, taxi_zones[['LocationID', 'borough', 'zone']], left_on='pulocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
mayo  = mayo.rename(columns={'borough': 'pickup_borough', 'zone': 'pickup_zone'})

# Eliminar la columna redundante
mayo  = mayo.drop('LocationID', axis=1)

# Fusión con la columna 'dolocationid'
mayo  = pd.merge(mayo, taxi_zones[['LocationID', 'borough', 'zone']], left_on='dolocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
mayo  = mayo.rename(columns={'borough': 'dropoff_borough', 'zone': 'dropoff_zone'})

# Eliminar la columna redundante
mayo  = mayo.drop('LocationID', axis=1)
mayo.to_parquet('mayo.parquet')

# %%
import pandas as pd

# Cargar el conjunto de datos de taxi_zones
taxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")

junio['hora_del_dia'] = junio['tpep_pickup_datetime'].dt.hour
junio['dia_de_la_semana'] = junio['tpep_pickup_datetime'].dt.dayofweek


# Fusión con la columna 'pulocationid'
junio = pd.merge(junio , taxi_zones[['LocationID', 'borough', 'zone']], left_on='pulocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
junio  = junio.rename(columns={'borough': 'pickup_borough', 'zone': 'pickup_zone'})

# Eliminar la columna redundante
junio  = junio.drop('LocationID', axis=1)

# Fusión con la columna 'dolocationid'
junio  = pd.merge(junio, taxi_zones[['LocationID', 'borough', 'zone']], left_on='dolocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
junio  = junio.rename(columns={'borough': 'dropoff_borough', 'zone': 'dropoff_zone'})

# Eliminar la columna redundante
junio  = junio.drop('LocationID', axis=1)

junio.to_parquet('junio.parquet')

# %%
import pandas as pd

# Cargar el conjunto de datos de taxi_zones
taxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")

julio['hora_del_dia'] = julio['tpep_pickup_datetime'].dt.hour
julio['dia_de_la_semana'] = julio['tpep_pickup_datetime'].dt.dayofweek

# Fusión con la columna 'pulocationid'
julio = pd.merge(julio , taxi_zones[['LocationID', 'borough', 'zone']], left_on='pulocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
julio  = julio.rename(columns={'borough': 'pickup_borough', 'zone': 'pickup_zone'})

# Eliminar la columna redundante
julio  = julio .drop('LocationID', axis=1)

# Fusión con la columna 'dolocationid'
julio  = pd.merge(julio, taxi_zones[['LocationID', 'borough', 'zone']], left_on='dolocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
julio  = julio.rename(columns={'borough': 'dropoff_borough', 'zone': 'dropoff_zone'})

# Eliminar la columna redundante
julio  = julio.drop('LocationID', axis=1)

julio.to_parquet('julio.parquet')

# %%
import pandas as pd

# Cargar el conjunto de datos de taxi_zones
taxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")

agosto['hora_del_dia'] = agosto['tpep_pickup_datetime'].dt.hour
agosto['dia_de_la_semana'] = agosto['tpep_pickup_datetime'].dt.dayofweek


# Fusión con la columna 'pulocationid'
agosto = pd.merge(agosto , taxi_zones[['LocationID', 'borough', 'zone']], left_on='pulocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
agosto  = agosto.rename(columns={'borough': 'pickup_borough', 'zone': 'pickup_zone'})

# Eliminar la columna redundante
agosto  = agosto .drop('LocationID', axis=1)

# Fusión con la columna 'dolocationid'
agosto  = pd.merge(agosto, taxi_zones[['LocationID', 'borough', 'zone']], left_on='dolocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
agosto  = agosto.rename(columns={'borough': 'dropoff_borough', 'zone': 'dropoff_zone'})

# Eliminar la columna redundante
agosto  = agosto.drop('LocationID', axis=1)

agosto.to_parquet('agosto.parquet')

# %%
agosto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2413401 entries, 0 to 2413400
# Data columns (total 26 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   vendorid               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   ratecodeid             float64
#  6   store_and_fwd_flag     object
#  7   pulocationid           int32
#  8   dolocationid           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
#  19  duracion               float64
#  20  hora_del_dia           int64
# ...

# %%
'''import pandas as pd

# Cargar el conjunto de datos de taxi_zones
taxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")

septiembre['hora_del_dia'] = septiembre['tpep_pickup_datetime'].dt.hour
septiembre['dia_de_la_semana'] = septiembre['tpep_pickup_datetime'].dt.dayofweek


# Fusión con la columna 'pulocationid'
septiembre = pd.merge(septiembre, taxi_zones[['LocationID', 'borough', 'zone']], left_on='pulocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
septiembre = septiembre.rename(columns={'borough': 'pickup_borough', 'zone': 'pickup_zone'})

# Eliminar la columna redundante
septiembre = septiembre.drop('LocationID', axis=1)

# Fusión con la columna 'dolocationid'
septiembre = pd.merge(septiembre, taxi_zones[['LocationID', 'borough', 'zone']], left_on='dolocationid', right_on='LocationID', how='left')

# Renombrar las columnas para evitar conflictos
septiembre = septiembre.rename(columns={'borough': 'dropoff_borough', 'zone': 'dropoff_zone'})

# Eliminar la columna redundante
septiembre = septiembre.drop('LocationID', axis=1)

septiembre.to_parquet('septiembre.parquet')
'''
# Out:
# 'import pandas as pd\n\n# Cargar el conjunto de datos de taxi_zones\ntaxi_zones = pd.read_csv("/content/drive/MyDrive/taxis_clean/taxi_zones.csv")\n\nseptiembre[\'hora_del_dia\'] = septiembre[\'tpep_pickup_datetime\'].dt.hour\nseptiembre[\'dia_de_la_semana\'] = septiembre[\'tpep_pickup_datetime\'].dt.dayofweek\n\n\n# Fusión con la columna \'pulocationid\'\nseptiembre = pd.merge(septiembre, taxi_zones[[\'LocationID\', \'borough\', \'zone\']], left_on=\'pulocationid\', right_on=\'LocationID\', how=\'left\')\n\n# Renombrar las columnas para evitar conflictos\nseptiembre = septiembre.rename(columns={\'borough\': \'pickup_borough\', \'zone\': \'pickup_zone\'})\n\n# Eliminar la columna redundante\nseptiembre = septiembre.drop(\'LocationID\', axis=1)\n\n# Fusión con la columna \'dolocationid\'\nseptiembre = pd.merge(septiembre, taxi_zones[[\'LocationID\', \'borough\', \'zone\']], left_on=\'dolocationid\', right_on=\'LocationID\', how=\'left\')\n\n# Renombrar las columnas para evitar conflic
# ...

# %%
#random_forest_model.importances

# %%
import matplotlib.pyplot as plt
import joblib

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import joblib
import matplotlib.pyplot as plt

# Cargar el DataFrame
# Asegúrate de tener 'viajes_taxis' cargado con los datos relevantes

# Seleccionar características y variable objetivo
features_regresion = ['trip_distance', 'hora_del_dia', 'dia_de_la_semana']
target_regresion = 'total_amount'

# Dividir datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(viajes_taxis[features_regresion], viajes_taxis[target_regresion], test_size=0.2, random_state=42)

# Modelos
modelos = {
    'RandomForest': RandomForestRegressor(n_estimators=100, random_state=42),
    'GradientBoosting': GradientBoostingRegressor(n_estimators=100, random_state=42),
    'AdaBoost': AdaBoostRegressor(n_estimators=100, random_state=42),
    'KNeighbors': KNeighborsRegressor(n_neighbors=3)
}

# Entrenar y guardar cada modelo
for nombre, modelo in modelos.items():
    modelo.fit(X_train, y_train)
    joblib.dump(modelo, f'{nombre}_model.joblib')

    # Hacer predicciones
    y_pred = modelo.predict(X_test)

    # Calcular el Mean Squared Error (MSE)
    mse = mean_squared_error(y_test, y_pred)
    print(f'{nombre} Mean Squared Error: {mse}')

    # Calcular el Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_test, y_pred)
    print(f'{nombre} Mean Absolute Error: {mae}')

    y_train_pred = modelo.predict(X_train)

    # Calcular el Mean Squared Error (MSE)
    mse_train = mean_squared_error(y_train, y_train_pred)
    print(f'{nombre} Mean Squared Error (Train): {mse_train}')

    # Calcular el Mean Absolute Error (MAE)
    mae_train = mean_absolute_error(y_train, y_train_pred)
    print(f'{nombre} Mean Absolute Error (Train): {mae_train}')

    # Crear una serie de números para el eje x (1 a 200)
    n_valores = 150
    eje_x = range(1, n_valores + 1)

    # Obtener solo los primeros 200 valores
    y_test_subset = y_test[:n_valores]
    y_pred_subset = y_pred[:n_valores]

    # Graficar las líneas para y_test y y_pred
    plt.figure(figsize=(10, 6))
    plt.plot(eje_x, y_test_subset, label='Valores Reales', marker='o', linestyle='-', color='blue')
    plt.plot(eje_x, y_pred_subset, label='Valores Predichos', marker='o', linestyle='-', color='red')

    # Configurar el gráfico
    plt.title(f'Comparación entre Valores Reales y Valores Predichos ({nombre})')
    plt.xlabel('Número de Valores')
    plt.ylabel('Valores')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'plot_{nombre}.png')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-705bdb5b0d29> in <cell line: 17>()
#      15
#      16 # Dividir datos en conjuntos de entrenamiento y prueba
# ---> 17 X_train, X_test, y_train, y_test = train_test_split(viajes_taxis[features_regresion], viajes_taxis[target_regresion], test_size=0.2, random_state=42)
#      18
#      19 # Modelos
#
# NameError: name 'viajes_taxis' is not defined

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, VotingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import joblib
import matplotlib.pyplot as plt

# Cargar el DataFrame
# Asegúrate de tener 'viajes_taxis' cargado con los datos relevantes

# Seleccionar características y variable objetivo
features_regresion = ['trip_distance', 'hora_del_dia', 'dia_de_la_semana']
target_regresion = 'total_amount'

# Dividir datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(viajes_taxis[features_regresion], viajes_taxis[target_regresion], test_size=0.2, random_state=42)

# Cargar los modelos entrenados
random_forest_model = joblib.load('RandomForest_model.joblib')
gradient_boosting_model = joblib.load('GradientBoosting_model.joblib')
adaboost_model = joblib.load('AdaBoost_model.joblib')
kneighbors_model = joblib.load('KNeighbors_model.joblib')

# Crear el VotingRegressor
voting_regressor = VotingRegressor([('random_forest', random_forest_model),
                                     ('gradient_boosting', gradient_boosting_model),
                                     ('adaboost', adaboost_model),
                                     ('kneighbors', kneighbors_model)])

# Entrenar el VotingRegressor
voting_regressor.fit(X_train, y_train)

# Hacer predicciones
y_pred_voting = voting_regressor.predict(X_test)

# Calcular el Mean Squared Error (MSE)
mse_voting = mean_squared_error(y_test, y_pred_voting)
print(f'VotingRegressor Mean Squared Error: {mse_voting}')

# Calcular el Mean Absolute Error (MAE)
mae_voting = mean_absolute_error(y_test, y_pred_voting)
print(f'VotingRegressor Mean Absolute Error: {mae_voting}')

# %%
# Cargar el modelo entrenado
#modelo_guardado = 'random_forest_model_2.pkl'
#loaded_model = joblib.load(modelo_guardado)
#loaded_model.feature_importances

# %%
import pandas as pd
import joblib

# Cargar el DataFrame con los nuevos datos
nuevos_datos = pd.DataFrame({
    'vendorid': [1, 2],
    'tpep_pickup_datetime': ['2023-09-01 00:15:37', '2023-09-01 00:18:40'],
    'tpep_dropoff_datetime': ['2023-09-01 00:20:21', '2023-09-01 00:30:28'],
    'passenger_count': [1.0, 2.0],
    'trip_distance': [0.80, 2.34],
    'ratecodeid': [1.0, 1.0],
    'store_and_fwd_flag': ['N', 'N'],
    'pulocationid': [163, 236],
    'dolocationid': [230, 233],
    'payment_type': [2, 1],
    'fare_amount': [6.5, 14.2],
    'extra': [3.5, 1.0],
    'mta_tax': [0.5, 0.5],
    'tip_amount': [0.00, 2.00],
    'tolls_amount': [0.0, 0.0],
    'improvement_surcharge': [1.0, 1.0],
    'total_amount': [11.50, 21.20],
    'congestion_surcharge': [2.5, 2.5],
    'airport_fee': [0.0, 0.0],
    'duracion': [4.733333, 11.800000],
    'hora_del_dia': [0, 0],
    'dia_de_la_semana': [4, 4]
})

# Cargar el modelo entrenado
modelo_guardado = 'random_forest_model_2.pkl'
loaded_model = joblib.load(modelo_guardado)

# Seleccionar características de los nuevos datos
features_nuevos_datos = nuevos_datos[features_regresion]

valores_a_predecir = nuevos_datos['total_amount']
print(valores_a_predecir)

# Hacer predicciones
predicciones_nuevos_datos = loaded_model.predict(features_nuevos_datos)

# Mostrar las predicciones
print('Predicciones para los nuevos datos:')
print(predicciones_nuevos_datos)

# %%
import matplotlib.pyplot as plt

# Obtener solo los primeros 200 valores
n_valores = 150
y_test_subset = y_test[:n_valores]
y_pred_subset = y_pred[:n_valores]

# Crear una serie de números para el eje x (1 a 200)
eje_x = range(1, n_valores + 1)

# Graficar las líneas para y_test y y_pred
plt.figure(figsize=(10, 6))
plt.plot(eje_x, y_test_subset, label='Valores Reales', marker='o', linestyle='-', color='blue')
plt.plot(eje_x, y_pred_subset, label='Valores Predichos', marker='o', linestyle='-', color='red')

# Configurar el gráfico
plt.title('Comparación entre Valores Reales y Valores Predichos')
plt.xlabel('Número de Valores')
plt.ylabel('Valores')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import joblib

# Cargar el DataFrame con los nuevos datos
nuevos_datos = pd.DataFrame({
    'vendorid': [1, 2],
    'tpep_pickup_datetime': ['2023-09-01 00:15:37', '2023-09-01 00:18:40'],
    'tpep_dropoff_datetime': ['2023-09-01 00:20:21', '2023-09-01 00:30:28'],
    'passenger_count': [1.0, 2.0],
    'trip_distance': [0.80, 2.34],
    'ratecodeid': [1.0, 1.0],
    'store_and_fwd_flag': ['N', 'N'],
    'pulocationid': [163, 236],
    'dolocationid': [230, 233],
    'payment_type': [2, 1],
    'fare_amount': [6.5, 14.2],
    'extra': [3.5, 1.0],
    'mta_tax': [0.5, 0.5],
    'tip_amount': [0.00, 2.00],
    'tolls_amount': [0.0, 0.0],
    'improvement_surcharge': [1.0, 1.0],
    'total_amount': [11.50, 21.20],
    'congestion_surcharge': [2.5, 2.5],
    'airport_fee': [0.0, 0.0],
    'duracion': [4.733333, 11.800000],
    'hora_del_dia': [0, 0],
    'dia_de_la_semana': [4, 4]
})

# Cargar el modelo entrenado
# modelo_guardado = 'random_forest_model_2.pkl'
# loaded_model = joblib.load(modelo_guardado)

# Seleccionar características de los nuevos datos
features_nuevos_datos = nuevos_datos[features_regresion]

# Hacer predicciones
predicciones_nuevos_datos = loaded_model.predict(features_nuevos_datos)

# Mostrar las predicciones
print('Predicciones para los nuevos datos:')
print(predicciones_nuevos_datos)

# %%
'''
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import joblib  # Para guardar el modelo

# Cargar el DataFrame
# Asegúrate de tener 'viajes_taxis' cargado con los datos relevantes

# Seleccionar características y variable objetivo
features_regresion = ['trip_distance', 'hora_del_dia', 'dia_de_la_semana']
target_regresion = 'total_amount'

# Dividir datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(viajes_taxis[features_regresion], viajes_taxis[target_regresion], test_size=0.2, random_state=42)

# Crear el pipeline
pipeline = Pipeline([
   ('scaler', StandardScaler()),  # Escalar los datos
    ('regressor', RandomForestRegressor())  # Regresor RandomForest por defecto
])

# Definir los hiperparámetros para RandomizedSearchCV
param_dist = {
    'regressor__n_estimators': [50, 100, 150],
    'regressor__max_depth': [None, 10, 20, 30],
    'regressor__min_samples_split': [2, 5, 10],
    'regressor__min_samples_leaf': [1, 2, 4]
}

# Configurar RandomizedSearchCV
random_search = RandomizedSearchCV(
    pipeline, param_distributions=param_dist, n_iter=10, scoring='neg_mean_squared_error', cv=10, random_state=42
)

# Entrenar el modelo con optimización de hiperparámetros
random_search.fit(X_train, y_train)

# Obtener el mejor modelo después de la búsqueda
best_model = random_search.best_estimator_

# Hacer predicciones
y_pred = best_model.predict(X_test)

# Calcular el Mean Squared Error (MSE) y el Mean Absolute Error (MAE)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')

# Visualizar la comparación entre los primeros 150 valores reales y predichos
n_valores = 150
y_test_subset = y_test[:n_valores]
y_pred_subset = y_pred[:n_valores]

eje_x = range(1, n_valores + 1)
plt.figure(figsize=(10, 6))
plt.plot(eje_x, y_test_subset, label='Valores Reales', marker='o', linestyle='-', color='blue')
plt.plot(eje_x, y_pred_subset, label='Valores Predichos', marker='o', linestyle='-', color='red')
plt.title('Comparación entre Valores Reales y Valores Predichos')
plt.xlabel('Número de Valores')
plt.ylabel('Valores')
plt.legend()
plt.grid(True)
plt.show()

# Guardar el modelo
joblib.dump(best_model, 'random_forest_model_2.pkl')
'''

# %%
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import VotingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
import pandas as pd

# Cargar el DataFrame
# Asegúrate de tener 'viajes_taxis' cargado con los datos relevantes

# Seleccionar características y variable objetivo
features_regresion = ['trip_distance', 'hora_del_dia', 'dia_de_la_semana']
target_regresion = 'total_amount'

# Dividir datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(viajes_taxis[features_regresion], viajes_taxis[target_regresion], test_size=0.2, random_state=42)

# Cargar modelos previamente entrenados
random_forest_model = joblib.load('RandomForest_model.joblib')
gradient_boosting_model = joblib.load('GradientBoosting_model.joblib')
adaboost_model = joblib.load('AdaBoost_model.joblib')
kneighbors_model = joblib.load('KNeighbors_model.joblib')

# Crear el VotingRegressor
voting_regressor = VotingRegressor([('random_forest', random_forest_model),
                                     ('gradient_boosting', gradient_boosting_model),
                                     ('adaboost', adaboost_model),
                                     ('kneighbors', kneighbors_model)])

# Entrenar el VotingRegressor
voting_regressor.fit(X_train, y_train)

# Hacer predicciones
y_pred_voting = voting_regressor.predict(X_test)

# Visualización de las predicciones y valores reales
plt.figure(figsize=(12, 6))
plt.plot(y_test.values[:200], label='Valores Reales', marker='o', linestyle='-', color='blue')
plt.plot(y_pred_voting[:200], label='Predicciones (Voting)', marker='o', linestyle='-', color='red')
plt.title('Comparación entre Valores Reales y Predicciones (Voting)')
plt.xlabel('Número de Valores')
plt.ylabel('Total Amount')
plt.legend()
plt.show()

# Guardar el modelo VotingRegressor
joblib.dump(voting_regressor, 'VotingRegressor_model.joblib')

# Guardar modelos individuales
joblib.dump(random_forest_model, 'RandomForest_model.joblib')
joblib.dump(gradient_boosting_model, 'GradientBoosting_model.joblib')
joblib.dump(adaboost_model, 'AdaBoost_model.joblib')
joblib.dump(kneighbors_model, 'KNeighbors_model.joblib')
