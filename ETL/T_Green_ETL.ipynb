# %% [markdown]
# # Taxis Verdes.

# %%
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d086ff96-36b9-4faa-8917-d6c28064e3eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d086ff96-36b9-4faa-8917-d6c28064e3eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Mes Enero.

# %%
tG1=pd.read_parquet('green_tripdata_2023-01.parquet')
print(tG1.shape)
tG1.head(1)
# Out:
# (68211, 20)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-01-01 00:26:10   2023-01-01 00:37:11                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           166           143              1.0           2.58
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0         14.9    1.0      0.5        4.03           0.0      None
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         24.18           1.0        1.0
#
#    congestion_surcharge
# 0                  2.75

# %%
print(tG1.columns)
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %% [markdown]
# | *Columna* | *Significado* |
# | --- | --- |
# | 	VendorID | Id del Vendedor. |
# | lpep_pickup_datetime | Fecha y hora de la Recogida del Usuario. |
# | lpep_dropoff_datetime | fecha y hora de la Bajada del Usuario. |
# | store_and_fwd_flag | Bandera de tienda y avance. |
# | RatecodeID | Id del código de tarifa. |
# | PULocationID | Id de ubicación del PU. |
# | DOLocationID	 |  Id de ubicación del DO . |
# | passenger_count | Reencuentro de pasajeros. |
# | trip_distance | Distancia del viaje. |
# | fare_amount | Monto de la tarifa. |
# | extra | Extra. |
# | mta_tax | Impuesto mta.  |
# | tip_amount | Propina. |
# | tolls_amount | Importe de peajes. |
# | ehail_fee | Tarifa extra por lluvia con granizo.|
# | improvement_surcharge | Recargo por Mejora. |
# | total_amount | Cantidad Total. |
# | payment_type | Tipo de Pago. |
# | trip_type | Tipo de Viaje. |
# | congestion_surcharge | Recargo extra por congestamiento. |

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tG1.columns:
  print(tG1[col].unique())
# Out:
# [2 1]
# ['2023-01-01T00:26:10.000000000' '2023-01-01T00:51:03.000000000'
#  '2023-01-01T00:35:12.000000000' ... '2023-01-31T23:46:00.000000000'
#  '2023-01-31T23:01:00.000000000' '2023-01-31T23:51:00.000000000']
# ['2023-01-01T00:37:11.000000000' '2023-01-01T00:57:49.000000000'
#  '2023-01-01T00:41:32.000000000' ... '2023-02-01T00:02:00.000000000'
#  '2023-01-31T23:19:00.000000000' '2023-02-01T00:07:00.000000000']
# ['N' 'Y' None]
# [ 1.  5.  4.  3.  2. 99. nan]
# [166  24 223  41 181 255  75  66 195  83  97   7  42  95 260 134 130 258
#  129 116  92  65  74  17 152 210 112  69 243  82 179 168  80  25 145 264
#   33 226  52 169  36  51 157  43 256 173  70 251  40 101  61 241 146 147
#  228 171 138  56 244 263 196  37 236 213  28 117  14 188 177  29 262 250
#   72 216  22  20 139  55 257 193 127 219   3 119 265 167 150  78 135 247
#   93 159  48  31  91  53 160  94  47 254 215  10  49 197   9  59 123 198
#   89 136 252 189  76  21  67  73  38 114 132 131 149 178 182  18 239 121
# ...

# %%
tG1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68211 entries, 0 to 68210
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               68211 non-null  int64
#  1   lpep_pickup_datetime   68211 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  68211 non-null  datetime64[ns]
#  3   store_and_fwd_flag     63887 non-null  object
#  4   RatecodeID             63887 non-null  float64
#  5   PULocationID           68211 non-null  int64
#  6   DOLocationID           68211 non-null  int64
#  7   passenger_count        63887 non-null  float64
#  8   trip_distance          68211 non-null  float64
#  9   fare_amount            68211 non-null  float64
#  10  extra                  68211 non-null  float64
#  11  mta_tax                68211 non-null  float64
#  12  tip_amount             68211 non-null  float64
#  13  tolls_amount           68211 non-null  float64
# ...

# %%
tG1.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  68211.000000  63887.000000  68211.000000  68211.000000
# mean       1.863028      1.117160     98.549735    138.429901
# std        0.343820      1.372913     61.244314     76.761311
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000     74.000000     74.000000
# 50%        2.000000      1.000000     75.000000    138.000000
# 75%        2.000000      1.000000    129.000000    219.000000
# max        2.000000     99.000000    265.000000    265.000000
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     63887.000000   68211.000000  68211.000000  68211.000000
# mean          1.315870       8.114852     16.603545      0.825431
# std           0.979054     585.105955     13.470121      1.269904
# min           0.000000       0.000000    -70.000000     -2.500000
# 25%           1.000000       1.110000      9.300000      0.000000
# ...

# %%
valoresUnicos=tG1['store_and_fwd_flag'].unique()
valoresUnicos
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1=tG1['DOLocationID'].unique()
valoresUnicos1
# Out:
# array([143,  43, 179, 238,  74, 262,  45,  75, 166, 140, 234, 148, 255,
#        186, 210, 129,  68, 260,  42,  24, 244, 146, 135, 173, 216, 142,
#        265, 164,   7,  83,  95, 130, 223,  80,  48, 263, 196, 250, 226,
#        239, 189,  41, 168, 162, 141,  33, 145, 151, 116, 195, 249, 235,
#        160,  98,  79, 229, 181, 193, 237, 233, 264, 102,  10,  37, 258,
#         82, 170,  61, 112, 231,  97,  17, 169,  96, 219, 243, 236,  56,
#         36, 114, 157, 161,  54,  90,  40, 188,  70,  63, 251, 101,  92,
#        153,  53,  57, 256,  65, 257, 138,  85,  52, 119, 241,  50,  78,
#        228, 211, 230, 218, 121, 163, 132, 192, 184, 113, 167,  28, 177,
#         86,  89, 205, 152,  88,  69,  16, 225, 137, 144,  66,  71, 127,
#        134, 194,  87,  76, 147, 158,   8, 227, 248, 246, 171, 247, 182,
#        180,   1, 106,  14, 198, 131, 213, 125, 197,  32, 220, 150, 207,
#         49,  55, 159,  18, 174, 122,  31,  25, 100,  35, 139, 185,  15,
# ...

# %%
SeleccionColumnas=['lpep_pickup_datetime',
                   'lpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

tG1=tG1[SeleccionColumnas]
print(tG1.shape)
tG1.head(1)
# Out:
# (68211, 13)
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-01-01 00:26:10   2023-01-01 00:37:11           166           143
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0           2.58         14.9    1.0      0.5        4.03
#
#    total_amount  payment_type  congestion_surcharge
# 0         24.18           1.0                  2.75

# %%
tG1.isna().sum()
# Out:
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID                0
# DOLocationID                0
# passenger_count          4324
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# total_amount                0
# payment_type             4324
# congestion_surcharge     4324
# dtype: int64

# %%
selccionColumnas1=['passenger_count','payment_type','congestion_surcharge']
tG1_nulos=tG1.dropna(subset=selccionColumnas1)
tG1=tG1_nulos
print(tG1.shape)
tG1.isna().sum()
# Out:
# (63887, 13)
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %%
def analizar_dataframe(tG1):
    nulos_por_columna = tG1.isnull().sum()
    duplicados = tG1.duplicated().sum()
    columnas_numericas = tG1.select_dtypes(include='number')
    plt.figure(figsize=(15,8))
    sns.boxplot(data=columnas_numericas)
    plt.xticks(rotation=45, ha='right')
    plt.show()
    return nulos_por_columna, duplicados

analizar_dataframe(tG1)
# Out:
# (lpep_pickup_datetime     0
#  lpep_dropoff_datetime    0
#  PULocationID             0
#  DOLocationID             0
#  passenger_count          0
#  trip_distance            0
#  fare_amount              0
#  extra                    0
#  mta_tax                  0
#  tip_amount               0
#  total_amount             0
#  payment_type             0
#  congestion_surcharge     0
#  dtype: int64,
#  0)

# %% [markdown]
# ## Mes Febrero.

# %%
tG2=pd.read_parquet('green_tripdata_2023-02.parquet')
print(tG2.shape)
tG2.head(1)
# Out:
# (64809, 20)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         1  2023-02-01 00:46:22   2023-02-01 01:05:57                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74           265              1.0           10.8
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         42.9    1.0      1.5         0.0           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0          45.4           2.0        1.0
#
#    congestion_surcharge
# 0                   0.0

# %%
print(tG2.columns)
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tG2.columns:
  print(tG2[col].unique())
# Out:
# [1 2]
# ['2023-02-01T00:46:22.000000000' '2023-02-01T00:05:09.000000000'
#  '2023-02-01T00:03:47.000000000' ... '2023-02-28T22:42:00.000000000'
#  '2023-02-28T23:21:00.000000000' '2023-02-28T23:10:00.000000000']
# ['2023-02-01T01:05:57.000000000' '2023-02-01T00:22:42.000000000'
#  '2023-02-01T00:27:30.000000000' ... '2023-02-28T22:59:00.000000000'
#  '2023-02-28T23:38:00.000000000' '2023-02-28T23:15:00.000000000']
# ['N' 'Y' None]
# [ 1.  5.  2.  4.  3. 99.  6. nan]
# [ 74 216   7  82  92 244  75  95  97 112  55 146 260 127 226 130 129 179
#   41  42 197 263 217 181 116 223 264  63 166  91 145  21  52  24  43  61
#   33 210  83 243 134 147 242  77 169 193 165 152 126  37 159  65 135 228
#  188 220 236 196 102 123  14 174  25  86 137  66  94 218  49 207   9  17
#  191  89 235  29 265 250 180 212  39 227 150  56  18  20  60  28  69 157
#  247 171 175  78  70  76 117  32 121 160 173  85 256 168 255 258  40  36
#  167 241 213  51  10 149 153  47 136 248 186  35 185 190  80 182 106 138
# ...

# %%
tG2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64809 entries, 0 to 64808
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               64809 non-null  int32
#  1   lpep_pickup_datetime   64809 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  64809 non-null  datetime64[ns]
#  3   store_and_fwd_flag     59988 non-null  object
#  4   RatecodeID             59988 non-null  float64
#  5   PULocationID           64809 non-null  int32
#  6   DOLocationID           64809 non-null  int32
#  7   passenger_count        59988 non-null  float64
#  8   trip_distance          64809 non-null  float64
#  9   fare_amount            64809 non-null  float64
#  10  extra                  64809 non-null  float64
#  11  mta_tax                64809 non-null  float64
#  12  tip_amount             64809 non-null  float64
#  13  tolls_amount           64809 non-null  float64
# ...

# %%
tG2.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  64809.000000  59988.000000  64809.000000  64809.000000
# mean       1.867920      1.136527     99.988273    139.065809
# std        0.338581      1.132523     61.711800     76.378947
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000     74.000000     74.000000
# 50%        2.000000      1.000000     75.000000    138.000000
# 75%        2.000000      1.000000    129.000000    219.000000
# max        2.000000     99.000000    265.000000    265.000000
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     59988.000000   64809.000000  64809.000000  64809.000000
# mean          1.294792      13.696354     16.646276      0.844270
# std           0.944409     931.311966     12.650412      1.280076
# min           0.000000       0.000000   -113.490000     -2.500000
# 25%           1.000000       1.130000      9.300000      0.000000
# ...

# %%
valoresUnicosf2=tG2['store_and_fwd_flag'].unique()
valoresUnicosf2
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1f2=tG2['DOLocationID'].unique()
valoresUnicos1f2
# Out:
# array([265, 196, 114, 239, 223,   7, 121,  42,  41,  97,  74, 188, 135,
#         95, 129, 146,  55, 260,  70, 159,  43,  82,  47, 130, 173, 235,
#        151, 226, 168, 197, 263, 243, 116, 242,  17, 141,  89, 216, 236,
#         61, 234,  73, 264,  53, 100,  75, 152, 162, 262, 145, 210, 142,
#         98, 238, 140, 179,  68,  33, 237,   4, 166, 161,  24, 231, 138,
#         83, 143, 213, 227, 244, 232, 150, 230, 137, 127, 203, 163,  52,
#         57, 167,  77, 169,  50, 171,  79,  31,  14, 132, 107,  66, 246,
#        164,  48, 193,  26, 233, 106,  25, 112, 229,  72,  87, 177,  29,
#         40,  92, 249,  71,  69, 170, 200, 102, 258, 198, 119, 160, 181,
#        256,  35,  49, 205, 174,  96, 217, 158,  94, 157, 144, 218, 207,
#          9, 220, 134,  11,  90, 202,  39, 165,  86, 191, 186,  28, 247,
#        126,  32, 261, 189,  93, 225,  65, 252, 222, 175, 224,  21,  56,
#        124, 195,  60,  80,  16, 248,  88,  76,  78, 214, 255,  62, 182,
# ...

# %%
SeleccionColumnas=['lpep_pickup_datetime',
                   'lpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

tG2=tG2[SeleccionColumnas]
print(tG2.shape)
tG2.head(1)
# Out:
# (64809, 13)
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-02-01 00:46:22   2023-02-01 01:05:57            74           265
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0           10.8         42.9    1.0      1.5         0.0
#
#    total_amount  payment_type  congestion_surcharge
# 0          45.4           2.0                   0.0

# %%
tG2.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID                0
# DOLocationID                0
# passenger_count          4821
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# total_amount                0
# payment_type             4821
# congestion_surcharge     4821
# dtype: int64

# %%
selccionColumnas2=['passenger_count','payment_type','congestion_surcharge']
tG2_nulos=tG2.dropna(subset=selccionColumnas2)
tG2=tG2_nulos
print(tG2.shape)
tG2.isna().sum()
# Out:
# (59988, 13)
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Marzo.

# %%
tG3=pd.read_parquet('green_tripdata_2023-03.parquet')
print(tG3.shape)
tG3.head(1)
# Out:
# (72044, 20)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-03-01 00:25:10   2023-03-01 00:35:47                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            82           196              1.0           2.36
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         13.5    1.0      0.5         0.0           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0          16.0           2.0        1.0
#
#    congestion_surcharge
# 0                   0.0

# %%
print(tG3.columns)
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tG3.columns:
  print(tG3[col].unique())
# Out:
# [2 1]
# ['2023-03-01T00:25:10.000000000' '2023-03-01T00:14:29.000000000'
#  '2023-02-28T22:59:46.000000000' ... '2023-03-31T23:09:00.000000000'
#  '2023-03-31T23:39:00.000000000' '2023-03-31T23:38:00.000000000']
# ['2023-03-01T00:35:47.000000000' '2023-03-01T00:25:04.000000000'
#  '2023-02-28T23:08:38.000000000' ... '2023-03-31T23:53:00.000000000'
#  '2023-03-31T23:40:00.000000000' '2023-04-01T00:01:00.000000000']
# ['N' 'Y' None]
# [ 1.  5.  4.  2.  3. 99. nan]
# [ 82   7 166 236  75 260  95 244  83 223 146 130  74 210 179 127 216  92
#   43 129 193 192  41  42  97  33  62 264 173 122 247 226 222  69  61  91
#  215 243 259  55  76 152  71  65  66  52 134 168  40 235 116  56  26 225
#   24  35 265 258   3 263  47  15 196  17 123 145 242 241 180  14 159  25
#  220 237 181  45  28 198  39 212  70 213 191  60 137 208 113 149  34 147
#   16 188  22 124 169 167  37  73 150 227  67 250  78 174  21  49  51 255
#  256 112 178  53 102 160  89 120 126 218   4  29 254  72 119 189 228 131
# ...

# %%
tG3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72044 entries, 0 to 72043
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               72044 non-null  int32
#  1   lpep_pickup_datetime   72044 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  72044 non-null  datetime64[ns]
#  3   store_and_fwd_flag     67507 non-null  object
#  4   RatecodeID             67507 non-null  float64
#  5   PULocationID           72044 non-null  int32
#  6   DOLocationID           72044 non-null  int32
#  7   passenger_count        67507 non-null  float64
#  8   trip_distance          72044 non-null  float64
#  9   fare_amount            72044 non-null  float64
#  10  extra                  72044 non-null  float64
#  11  mta_tax                72044 non-null  float64
#  12  tip_amount             72044 non-null  float64
#  13  tolls_amount           72044 non-null  float64
# ...

# %%
tG3.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  72044.000000  67507.000000  72044.000000  72044.000000
# mean       1.865443      1.145703     98.437413    137.613556
# std        0.341252      1.225735     60.481870     76.169705
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000     74.000000     74.000000
# 50%        2.000000      1.000000     75.000000    138.000000
# 75%        2.000000      1.000000    129.000000    216.000000
# max        2.000000     99.000000    265.000000    265.000000
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     67507.000000   72044.000000  72044.000000  72044.000000
# mean          1.286844      12.449511     17.018203      0.878109
# std           0.923652     641.094653     13.832399      1.297642
# min           0.000000       0.000000   -115.000000     -5.000000
# 25%           1.000000       1.100000      9.300000      0.000000
# ...

# %%
valoresUnicosM3=tG3['store_and_fwd_flag'].unique()
valoresUnicosM3
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1M3=tG3['DOLocationID'].unique()
valoresUnicos1M3
# Out:
# array([196,   7,  74, 229, 235, 160, 264,  41, 223, 260, 193, 145, 191,
#        134, 152, 173, 155,  82, 179, 139, 119, 247, 186, 124, 220, 121,
#         28,  83,  95, 192,  75, 216, 263, 116, 239,  42,  17, 265, 226,
#        129, 162, 164, 157,  80,  56,  70, 127,  24, 102, 140, 166, 138,
#        142, 141,  53, 236, 238, 244,  43,  86, 136,  25,  68,  14, 151,
#         76, 168, 122, 230, 113, 163, 237, 246,  69,  34, 170, 233, 262,
#        227, 243,  55, 261, 130, 132,  94, 197,  89, 249,  92, 234, 159,
#         61, 146,  26,  88,  73, 218, 107, 177, 143, 100, 242, 174, 231,
#         90, 128, 250,  48, 181,   3,  79, 137,  47,  98,  49, 131,  35,
#         51, 205, 161,  33, 195,  16,  85, 188,  40, 189, 256, 198,  45,
#        259,  54,  13, 135, 202, 248, 120,  62,  15,  32,  36, 208,  96,
#        149, 167, 126,  65, 213, 178,  50,  66, 114,  18, 185,  81,  10,
#        225, 147, 171,  60,  72, 150, 123,   9, 169, 241, 183,  97, 210,
# ...

# %%
SeleccionColumnas=['lpep_pickup_datetime',
                   'lpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

tG3=tG3[SeleccionColumnas]
print(tG3.shape)
tG3.head(1)
# Out:
# (72044, 13)
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-03-01 00:25:10   2023-03-01 00:35:47            82           196
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0           2.36         13.5    1.0      0.5         0.0
#
#    total_amount  payment_type  congestion_surcharge
# 0          16.0           2.0                   0.0

# %%
tG3.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID                0
# DOLocationID                0
# passenger_count          4537
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# total_amount                0
# payment_type             4537
# congestion_surcharge     4537
# dtype: int64

# %%
selccionColumnas3=['passenger_count','payment_type','congestion_surcharge']
tG3_nulos=tG3.dropna(subset=selccionColumnas3)
tG3=tG3_nulos
print(tG3.shape)
tG3.isna().sum()
# Out:
# (67507, 13)
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Abril.

# %%
tG4=pd.read_parquet('green_tripdata_2023-04.parquet')
print(tG4.shape)
tG4.head(1)
# Out:
# (65392, 20)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-04-01 00:01:46   2023-04-01 00:11:42                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            75            42              1.0           2.62
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         13.5    1.0      0.5         3.0           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0          19.0           1.0        1.0
#
#    congestion_surcharge
# 0                   0.0

# %%
print(tG4.columns)
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tG4.columns:
  print(tG4[col].unique())
# Out:
# [2 1]
# ['2023-04-01T00:01:46.000000000' '2023-04-01T00:21:32.000000000'
#  '2023-04-01T00:03:14.000000000' ... '2023-04-30T23:25:00.000000000'
#  '2023-04-30T23:36:00.000000000' '2023-04-30T23:24:00.000000000']
# ['2023-04-01T00:11:42.000000000' '2023-04-01T00:53:16.000000000'
#  '2023-04-01T00:16:54.000000000' ... '2023-04-30T23:40:00.000000000'
#  '2023-04-30T23:57:00.000000000' '2023-04-30T23:44:00.000000000']
# ['N' 'Y' None]
# [ 1.  5.  4.  3.  2. 99. nan]
# [ 75 166  74  66 255 112   7  65 129 260  73  95 244  97 130  80 179 223
#  134  41 210  55  25  82 264  92  42 159 145  36 147 146  39 256  83 181
#  127  52 135 119 173 157  57 212 226 106  69 235 116 168 152 198 193  24
#  192  43 232 243 182 220  11  98  62 236  70  17  14 216 196 197  33 188
#   49 195 189 228 208  61 247 263  47 241 172 240 169  34 202  31  10  18
#  136 213   3  76 154  20 120  21  78 124 194 257  40 167  89 215 160 242
#  238  56  29 222  28  67  38 126  35 250  85 138  94 171  22 205 133  54
# ...

# %%
tG4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65392 entries, 0 to 65391
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               65392 non-null  int32
#  1   lpep_pickup_datetime   65392 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  65392 non-null  datetime64[ns]
#  3   store_and_fwd_flag     60910 non-null  object
#  4   RatecodeID             60910 non-null  float64
#  5   PULocationID           65392 non-null  int32
#  6   DOLocationID           65392 non-null  int32
#  7   passenger_count        60910 non-null  float64
#  8   trip_distance          65392 non-null  float64
#  9   fare_amount            65392 non-null  float64
#  10  extra                  65392 non-null  float64
#  11  mta_tax                65392 non-null  float64
#  12  tip_amount             65392 non-null  float64
#  13  tolls_amount           65392 non-null  float64
# ...

# %%
tG4.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  65392.000000  60910.000000  65392.000000  65392.000000
# mean       1.868822      1.152487     99.021730    139.423140
# std        0.337598      1.013509     60.677004     76.233616
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000     74.000000     74.000000
# 50%        2.000000      1.000000     75.000000    138.000000
# 75%        2.000000      1.000000    129.000000    223.000000
# max        2.000000     99.000000    265.000000    265.000000
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     60910.000000   65392.000000  65392.000000  65392.000000
# mean          1.273436      12.811717     17.657479      0.835561
# std           0.896002     658.221415     14.571613      1.298586
# min           0.000000       0.000000   -225.080000     -2.500000
# 25%           1.000000       1.150000      9.300000      0.000000
# ...

# %%
valoresUnicosA4=tG4['store_and_fwd_flag'].unique()
valoresUnicosA4
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1A4=tG4['DOLocationID'].unique()
valoresUnicos1A4
# Out:
# array([ 42, 107, 238,  33, 225, 140, 158, 263,   7, 179, 262,  24, 257,
#        129, 236,  79,  73,  95, 151,  89, 229, 256, 244, 130, 189, 116,
#        260, 102, 173,  66,  70,  28, 239,  82, 123,  55,  25,  83,  16,
#        264, 205,  97, 252,  75, 182, 246,  10,  74,  36,  61, 113, 234,
#        142, 188, 145, 164, 147, 249, 235, 135, 146, 197,  35,  62, 186,
#         91, 166, 170,  48, 226, 121,  47, 112, 169, 144, 237, 157, 255,
#         17, 223,  68,  56,  80,  41, 136, 141, 228, 138, 161,  92, 208,
#        258,  54, 265,  50, 243,  96, 132, 198, 159, 168,  53, 247, 193,
#        120,   6,  37, 127, 162, 152,  43, 192, 100,  26,  65,  60, 117,
#        218, 220,  40, 134, 224, 119,   4, 122, 181,   1, 143, 211,  88,
#        163,  45, 215, 232, 209, 194, 231, 114,  14, 167, 124,  69,  49,
#        106, 216, 195,  20, 190, 171, 233, 230,  87,  64,  52, 125, 245,
#         93, 137, 148, 155, 196,  67, 160, 227, 261,  76, 191, 153, 133,
# ...

# %%
SeleccionColumnas=['lpep_pickup_datetime',
                   'lpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

tG4=tG4[SeleccionColumnas]
print(tG4.shape)
tG4.head(1)
# Out:
# (65392, 13)
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-04-01 00:01:46   2023-04-01 00:11:42            75            42
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0           2.62         13.5    1.0      0.5         3.0
#
#    total_amount  payment_type  congestion_surcharge
# 0          19.0           1.0                   0.0

# %%
tG4.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID                0
# DOLocationID                0
# passenger_count          4482
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# total_amount                0
# payment_type             4482
# congestion_surcharge     4482
# dtype: int64

# %%
selccionColumnas4=['passenger_count','payment_type','congestion_surcharge']
tG4_nulos=tG4.dropna(subset=selccionColumnas4)
tG4=tG4_nulos
print(tG4.shape)
tG4.isna().sum()
# Out:
# (60910, 13)
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Mayo.

# %%
tG5=pd.read_parquet('green_tripdata_2023-05.parquet')
print(tG5.shape)
tG5.head(1)
# Out:
# (69174, 20)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-05-01 00:52:10   2023-05-01 01:05:26                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           244           213              1.0           6.99
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         28.9    1.0      0.5         0.0           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0          31.4           1.0        1.0
#
#    congestion_surcharge
# 0                   0.0

# %%
print(tG5.columns)
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tG5.columns:
  print(tG5[col].unique())
# Out:
# [2 1]
# ['2023-05-01T00:52:10.000000000' '2023-05-01T00:29:49.000000000'
#  '2023-05-01T00:25:19.000000000' ... '2023-05-31T23:39:00.000000000'
#  '2023-05-31T23:42:00.000000000' '2023-05-31T23:10:00.000000000']
# ['2023-05-01T01:05:26.000000000' '2023-05-01T00:50:11.000000000'
#  '2023-05-01T00:32:12.000000000' ... '2023-05-31T23:55:00.000000000'
#  '2023-06-01T00:11:00.000000000' '2023-05-31T23:24:00.000000000']
# ['N' 'Y' None]
# [ 1.  5.  2.  3.  4. 99. nan]
# [244  33  82  69 169  75  41  74 166  95 129 173  42  92 182 127   7  97
#  130 243 260 116  83 250  25 134 242  70 264 108 248  76  55  24  43  40
#  198  37  28 196 263 213 223 238 123  65  89 146 207 152  52 142 136  72
#   14 151 205  61 247 193 145 259  17 168 159 265 102 226 200  66 206 236
#  132  98  35  34  93 188 174 181  21 225  49 122 189 241 210  22  94 153
#  185 255 197 220 258 165 124 212 119  46  51 256 135  18 157  80 121 150
#  215 126  78 217  29 179 192  53 177 170 155  20 191 106 160 112 218 138
# ...

# %%
tG5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69174 entries, 0 to 69173
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               69174 non-null  int32
#  1   lpep_pickup_datetime   69174 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  69174 non-null  datetime64[ns]
#  3   store_and_fwd_flag     64442 non-null  object
#  4   RatecodeID             64442 non-null  float64
#  5   PULocationID           69174 non-null  int32
#  6   DOLocationID           69174 non-null  int32
#  7   passenger_count        64442 non-null  float64
#  8   trip_distance          69174 non-null  float64
#  9   fare_amount            69174 non-null  float64
#  10  extra                  69174 non-null  float64
#  11  mta_tax                69174 non-null  float64
#  12  tip_amount             69174 non-null  float64
#  13  tolls_amount           69174 non-null  float64
# ...

# %%
tG5.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  69174.000000  64442.000000  69174.000000  69174.000000
# mean       1.863345      1.162798     98.859441    140.348599
# std        0.343486      1.018955     60.533119     76.187368
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000     74.000000     74.000000
# 50%        2.000000      1.000000     75.000000    138.000000
# 75%        2.000000      1.000000    129.000000    223.000000
# max        2.000000     99.000000    265.000000    265.000000
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     64442.000000   69174.000000  69174.000000  69174.000000
# mean          1.269064      18.591360     18.187894      0.894679
# std           0.883788    1274.880857     15.477541      1.359046
# min           0.000000       0.000000    -95.000000     -5.000000
# 25%           1.000000       1.170000     10.000000      0.000000
# ...

# %%
valoresUnicosM5=tG5['store_and_fwd_flag'].unique()
valoresUnicosM5
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1M5=tG2['DOLocationID'].unique()
valoresUnicos1M5
# Out:
# array([265, 196, 114, 239, 223,   7, 121,  42,  41,  97,  74, 188, 135,
#         95, 129, 146,  55, 260,  70, 159,  43,  82,  47, 130, 173, 235,
#        151, 226, 168, 197, 263, 243, 116, 242,  17, 141,  89, 216, 236,
#         61, 234,  73, 264,  53, 100,  75, 152, 162, 262, 145, 210, 142,
#         98, 238, 140, 179,  68,  33, 237,   4, 166, 161,  24, 231, 138,
#         83, 143, 213, 227, 244, 232, 150, 230, 137, 127, 203, 163,  52,
#         57, 167,  77, 169,  50, 171,  79,  31,  14, 132, 107,  66, 246,
#        164,  48, 193,  26, 233, 106,  25, 112, 229,  72,  87, 177,  29,
#         40,  92, 249,  71,  69, 170, 200, 102, 258, 198, 119, 160, 181,
#        256,  35,  49, 205, 174,  96, 217, 158,  94, 157, 144, 218, 207,
#          9, 220, 134,  11,  90, 202,  39, 165,  86, 191, 186,  28, 247,
#        126,  32, 261, 189,  93, 225,  65, 252, 222, 175, 224,  21,  56,
#        124, 195,  60,  80,  16, 248,  88,  76,  78, 214, 255,  62, 182,
# ...

# %%
SeleccionColumnas=['lpep_pickup_datetime',
                   'lpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

tG5=tG5[SeleccionColumnas]
print(tG5.shape)
tG5.head(1)
# Out:
# (69174, 13)
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-05-01 00:52:10   2023-05-01 01:05:26           244           213
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0           6.99         28.9    1.0      0.5         0.0
#
#    total_amount  payment_type  congestion_surcharge
# 0          31.4           1.0                   0.0

# %%
tG5.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID                0
# DOLocationID                0
# passenger_count          4732
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# total_amount                0
# payment_type             4732
# congestion_surcharge     4732
# dtype: int64

# %%
selccionColumnas5=['passenger_count','payment_type','congestion_surcharge']
tG5_nulos=tG5.dropna(subset=selccionColumnas5)
tG5=tG5_nulos
print(tG5.shape)
tG5.isna().sum()
# Out:
# (64442, 13)
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Junio.

# %%
tG6=pd.read_parquet('green_tripdata_2023-06.parquet')
print(tG6.shape)
tG6.head(1)
# Out:
# (65550, 20)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-06-01 00:32:25   2023-06-01 00:39:06                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.84
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          7.9    1.0      0.5        2.08           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         12.48           1.0        1.0
#
#    congestion_surcharge
# 0                   0.0

# %%
print(tG6.columns)
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tG6.columns:
  print(tG6[col].unique())
# Out:
# [2 1]
# ['2023-06-01T00:32:25.000000000' '2023-06-01T00:39:07.000000000'
#  '2023-06-01T00:35:59.000000000' ... '2023-06-30T23:31:00.000000000'
#  '2023-06-30T23:12:00.000000000' '2023-06-30T23:36:00.000000000']
# ['2023-06-01T00:39:06.000000000' '2023-06-01T00:51:59.000000000'
#  '2023-06-01T00:57:06.000000000' ... '2023-06-30T23:22:00.000000000'
#  '2023-06-30T23:32:00.000000000' '2023-06-30T23:48:00.000000000']
# ['N' 'Y' None]
# [ 1.  5.  2.  4.  3.  6. nan]
# [ 74  41  97  75  33  42  95   7  80  61 146 121 129 260 130 244 168 116
#  264  82  25 171 173  49 166 136 262 208  92  21  56 134 191 149 252  83
#   55 236  43  52 243 188  40  24 226  65 152  89  17 220 212  81 223 117
#   10 181  94  76 228 178 182 217 247 193 192  29 126 241 189  72  86 135
#  196 145 127  28 179  69 225 213  85 177 159  11 227 263 248 108 167  93
#   70  66 235  53 231 216   1  71 253 119 195 174 197  14 210 255 256 205
#  154  36 180 157  96  20  77  37 132 138 222 242 250 254 165 112 102 123
# ...

# %%
tG6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65550 entries, 0 to 65549
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               65550 non-null  int32
#  1   lpep_pickup_datetime   65550 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  65550 non-null  datetime64[ns]
#  3   store_and_fwd_flag     60359 non-null  object
#  4   RatecodeID             60359 non-null  float64
#  5   PULocationID           65550 non-null  int32
#  6   DOLocationID           65550 non-null  int32
#  7   passenger_count        60359 non-null  float64
#  8   trip_distance          65550 non-null  float64
#  9   fare_amount            65550 non-null  float64
#  10  extra                  65550 non-null  float64
#  11  mta_tax                65550 non-null  float64
#  12  tip_amount             65550 non-null  float64
#  13  tolls_amount           65550 non-null  float64
# ...

# %%
tG6.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  65550.000000  60359.000000  65550.000000  65550.000000
# mean       1.875057      1.160076     98.453059    139.621876
# std        0.330657      0.772654     60.833665     76.726747
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000     74.000000     74.000000
# 50%        2.000000      1.000000     75.000000    138.000000
# 75%        2.000000      1.000000    127.000000    223.000000
# max        2.000000      6.000000    265.000000    265.000000
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     60359.000000   65550.000000  65550.000000  65550.000000
# mean          1.283007      22.430450     18.892448      0.882613
# std           0.904936    1114.401748     22.605564      1.327904
# min           0.000000       0.000000   -240.000000     -2.500000
# 25%           1.000000       1.180000     10.000000      0.000000
# ...

# %%
valoresUnicosJ6=tG6['store_and_fwd_flag'].unique()
valoresUnicosJ6
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1J6=tG6['DOLocationID'].unique()
valoresUnicos1J6
# Out:
# array([ 42, 229,  89, 263,  48, 159, 142,  75, 152,  95, 262, 236, 188,
#          7, 162,  17, 264, 129, 135,  83, 215, 219, 238,  50, 116, 244,
#         97, 223,  64, 168, 247, 140,  70, 260,  82, 171,  41,  28,  92,
#        173, 186, 138, 237, 106, 246, 132,  47, 210, 166,  74,  63, 201,
#         43, 233, 252,  55, 167, 243,  24,  56,  67, 164, 151, 265, 239,
#        227,  21,  33, 112, 226,  65, 130,  93, 143, 121, 170, 141, 146,
#        137, 119,  36, 235,  25, 113, 181, 145, 196, 161, 123, 100, 107,
#        218,  79, 158, 197, 163, 234,  69, 261,  49,  87, 193,  10, 102,
#        200, 157,  78, 192, 108,  76, 216,   9, 169, 259,  35,  61,  98,
#         90, 183,  19,  60,  53,  66,  37,  68,  40,  91,   8, 230, 189,
#        225, 127,  62, 160, 220, 175, 122, 242,  72, 134, 203, 254, 149,
#         38, 148, 177, 228, 249, 179, 126, 224, 139, 131, 101, 207, 231,
#        257, 258, 133,  22,  13, 232, 185, 213, 125, 217,  71, 136, 202,
# ...

# %%
SeleccionColumnas=['lpep_pickup_datetime',
                   'lpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

tG6=tG6[SeleccionColumnas]
print(tG6.shape)
tG6.head(1)
# Out:
# (65550, 13)
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-06-01 00:32:25   2023-06-01 00:39:06            74            42
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0           0.84          7.9    1.0      0.5        2.08
#
#    total_amount  payment_type  congestion_surcharge
# 0         12.48           1.0                   0.0

# %%
tG6.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID                0
# DOLocationID                0
# passenger_count          5191
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# total_amount                0
# payment_type             5191
# congestion_surcharge     5191
# dtype: int64

# %%
selccionColumnas6=['passenger_count','payment_type','congestion_surcharge']
tG6_nulos=tG6.dropna(subset=selccionColumnas6)
tG6=tG6_nulos
print(tG6.shape)
tG6.isna().sum()
# Out:
# (60359, 13)
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Julio.

# %%
tG7=pd.read_parquet('green_tripdata_2023-07.parquet')
print(tG7.shape)
tG7.head(1)
# Out:
# (61343, 20)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-07-01 00:08:06   2023-07-01 00:21:24                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            75           170              2.0           3.45
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         17.0    1.0      0.5        4.45           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0          26.7           1.0        1.0
#
#    congestion_surcharge
# 0                  2.75

# %%
print(tG7.columns)
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tG7.columns:
  print(tG7[col].unique())
# Out:
# [2 1]
# ['2023-07-01T00:08:06.000000000' '2023-07-01T00:56:14.000000000'
#  '2023-06-30T23:47:32.000000000' ... '2023-07-31T23:27:57.000000000'
#  '2023-07-31T23:20:00.000000000' '2023-07-31T23:30:00.000000000']
# ['2023-07-01T00:21:24.000000000' '2023-07-01T01:03:28.000000000'
#  '2023-06-30T23:47:35.000000000' ... '2023-07-31T23:35:51.000000000'
#  '2023-07-31T23:35:00.000000000' '2023-07-31T23:54:00.000000000']
# ['N' 'Y' None]
# [ 1.  5.  4.  3.  2. 99. nan]
# [ 75  42  33  74 166  66   7 244 153  80  41 129 255 223  85 264 260 193
#  179 212 130  65  27  95  36 134  55 173  25 216 127 226  52 181  83 157
#  247 152 256  92  82 210 112 196  29 121 145  97 131 165 243 116 217 198
#  200  70 254  24  43  56 132  61 191  28  17 117 263 208 151  89 265  10
#  213  62 123 219 197 220 135 225 167  14  47 159 215 138 253  49  21 262
#   53 150 136  93  76 242 235 146  18 236 195  40 174 119 168  60  91 106
#  188  37 126 257 248 227  78 156 124  35  39 108 185 222 228 190  69 169
# ...

# %%
tG7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61343 entries, 0 to 61342
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               61343 non-null  int32
#  1   lpep_pickup_datetime   61343 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  61343 non-null  datetime64[ns]
#  3   store_and_fwd_flag     56611 non-null  object
#  4   RatecodeID             56611 non-null  float64
#  5   PULocationID           61343 non-null  int32
#  6   DOLocationID           61343 non-null  int32
#  7   passenger_count        56611 non-null  float64
#  8   trip_distance          61343 non-null  float64
#  9   fare_amount            61343 non-null  float64
#  10  extra                  61343 non-null  float64
#  11  mta_tax                61343 non-null  float64
#  12  tip_amount             61343 non-null  float64
#  13  tolls_amount           61343 non-null  float64
# ...

# %%
tG7.describe()
# Out:
#            VendorID   RatecodeID  PULocationID  DOLocationID  passenger_count  \
# count  61343.000000  56611.00000  61343.000000  61343.000000     56611.000000
# mean       1.875259      1.18908     98.798771    139.417994         1.284485
# std        0.330428      1.16398     61.047394     76.470267         0.887123
# min        1.000000      1.00000      1.000000      1.000000         0.000000
# 25%        2.000000      1.00000     74.000000     74.000000         1.000000
# 50%        2.000000      1.00000     75.000000    138.000000         1.000000
# 75%        2.000000      1.00000    129.000000    223.000000         1.000000
# max        2.000000     99.00000    265.000000    265.000000         7.000000
#
#        trip_distance   fare_amount        extra       mta_tax    tip_amount  \
# count   61343.000000  61343.000000  61343.00000  61343.000000  61343.000000
# mean       23.458045     18.795827      0.83926      0.559334      2.338927
# ...

# %%
valoresUnicosJ7=tG7['store_and_fwd_flag'].unique()
valoresUnicosJ7
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1J7=tG7['DOLocationID'].unique()
valoresUnicos1J7
# Out:
# array([170, 262,  42,  75,  74, 238, 224,  79,  36, 244,  37, 173,  41,
#        143, 223, 229,  85, 264, 151, 116, 157, 179, 198, 208, 193, 130,
#        191, 127,  49,  27, 121, 112, 148,  25, 216, 134, 188, 196,  61,
#         95, 161, 213,   7,  80, 218,  28, 189, 227, 169, 239,  83,  70,
#         48, 263, 256, 129,  82,  14, 215,  17,  33, 197, 171, 260, 145,
#        132, 164, 168, 250, 235, 167, 255,  92, 160, 144, 135, 236, 243,
#         29, 232,  40, 192, 225, 230, 237, 141, 131, 249, 220,   4,  69,
#         66, 163, 231, 258, 138, 162, 166, 140, 211, 152,  76,  55, 142,
#        186, 241, 107,  47, 254,  24, 234,  10, 226, 265, 233, 117, 159,
#        122, 180, 119, 181, 100,  68,  89,  96, 228,  97, 247,  72,  65,
#        195,  88,  43,  22,  56, 114,  62,  90,   1,  50, 102, 150, 201,
#        246, 210, 177,  35, 252,  38,  13,   8, 190,  52,  45, 153,  94,
#         53,  60, 146, 212, 155, 106, 240,  93, 205,  54, 259, 194, 253,
# ...

# %%
SeleccionColumnas=['lpep_pickup_datetime',
                   'lpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

tG7=tG7[SeleccionColumnas]
print(tG7.shape)
tG7.head(1)
# Out:
# (61343, 13)
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-07-01 00:08:06   2023-07-01 00:21:24            75           170
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              2.0           3.45         17.0    1.0      0.5        4.45
#
#    total_amount  payment_type  congestion_surcharge
# 0          26.7           1.0                  2.75

# %%
tG7.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID                0
# DOLocationID                0
# passenger_count          4732
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# total_amount                0
# payment_type             4732
# congestion_surcharge     4732
# dtype: int64

# %%
selccionColumnas7=['passenger_count','payment_type','congestion_surcharge']
tG7_nulos=tG7.dropna(subset=selccionColumnas7)
tG7=tG7_nulos
print(tG7.shape)
tG7.isna().sum()
# Out:
# (56611, 13)
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Agosto.

# %%
tG8=pd.read_parquet('green_tripdata_2023-08.parquet')
print(tG8.shape)
tG8.head(1)
# Out:
# (60649, 20)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-08-01 00:03:21   2023-08-01 00:07:34                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0             7             7              1.0           0.81
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          6.5    1.0      0.5         2.7           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0          11.7           1.0        1.0
#
#    congestion_surcharge
# 0                   0.0

# %%
print(tG8.columns)
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tG8.columns:
  print(tG8[col].unique())
# Out:
# [2 1]
# ['2023-08-01T00:03:21.000000000' '2023-08-01T00:59:16.000000000'
#  '2023-07-31T23:59:42.000000000' ... '2023-08-31T22:50:00.000000000'
#  '2023-08-31T23:08:00.000000000' '2023-08-31T23:14:00.000000000']
# ['2023-08-01T00:07:34.000000000' '2023-08-01T01:10:50.000000000'
#  '2023-08-01T00:27:25.000000000' ... '2023-08-31T22:54:00.000000000'
#  '2023-09-01T00:07:00.000000000' '2023-08-31T23:48:00.000000000']
# ['N' 'Y' None]
# [ 1.  5.  2.  4.  3. 99. nan]
# [  7  24  83  74 127  43 244  82 152  25 112 166 119 247  60 130 243  75
#  226 256 218 134 252  42  95 129 179  69  56  41 260 235  92 169 254  18
#  242  70 214 181 116 102 215  29  33  76  55 145 207  52 264 177 236  97
#   65 262 101 123  49 216 153  10 202  32  78 258  72  71  91 223 191 193
#   28 213 225 146 157  35  26 220 168 120 159 241 198 196 135 197 136  94
#  185 201  86  81  66 189 182  61 210 170 222 227 132 137 133  73 205 155
#  232  17 263 173 195  11  19   9 208  80 167 265  39  47 255 122  22 178
# ...

# %%
tG8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60649 entries, 0 to 60648
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               60649 non-null  int32
#  1   lpep_pickup_datetime   60649 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  60649 non-null  datetime64[ns]
#  3   store_and_fwd_flag     56769 non-null  object
#  4   RatecodeID             56769 non-null  float64
#  5   PULocationID           60649 non-null  int32
#  6   DOLocationID           60649 non-null  int32
#  7   passenger_count        56769 non-null  float64
#  8   trip_distance          60649 non-null  float64
#  9   fare_amount            60649 non-null  float64
#  10  extra                  60649 non-null  float64
#  11  mta_tax                60649 non-null  float64
#  12  tip_amount             60649 non-null  float64
#  13  tolls_amount           60649 non-null  float64
# ...

# %%
tG8.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  60649.000000  56769.000000  60649.000000  60649.000000
# mean       1.869017      1.200109     96.991179    139.320005
# std        0.337385      1.033326     59.539639     76.148484
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000     69.000000     74.000000
# 50%        2.000000      1.000000     75.000000    138.000000
# 75%        2.000000      1.000000    116.000000    219.000000
# max        2.000000     99.000000    265.000000    265.000000
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     56769.000000   60649.000000  60649.000000  60649.000000
# mean          1.285402      26.994453     19.425460      0.910056
# std           0.904976    1403.653372     19.003167      1.362014
# min           0.000000       0.000000   -160.000000     -2.500000
# 25%           1.000000       1.170000     10.000000      0.000000
# ...

# %%
valoresUnicosA8=tG8['store_and_fwd_flag'].unique()
valoresUnicosA8
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1A8=tG8['DOLocationID'].unique()
valoresUnicos1A8
# Out:
# array([  7,  48,  76, 161,  94, 238, 243, 129, 152,  41, 262, 166, 181,
#         54, 119, 167,  20, 130, 116, 132, 173, 255, 148,  82, 215, 102,
#        252,  42,  69,  72, 135, 226, 265, 264, 225, 134, 126, 160, 138,
#        244, 157, 235,  51,  55,  88,  75, 240, 136, 197, 223,  56, 211,
#        230,  74, 142, 196, 159,  87, 162, 127,  95, 229, 236, 140, 260,
#         77, 237, 145, 168, 207, 192, 141,  60,  93,  65, 151,  13,  33,
#         37,  35, 205, 263, 253, 121, 100,  70, 233,  24, 231, 171,  67,
#        113,  52, 164, 170, 246, 137, 112,  10, 186, 239,  73,  47,  92,
#        107, 163, 224,  97, 188,  43, 193,  78, 228,  71,  32, 143,  49,
#        158,  12, 209,  68,  90, 124, 182, 247,  53,  98, 219, 217, 220,
#         45, 191, 242, 218, 114,  83, 117,  61, 232,  66,  25,   1,  28,
#        174,  17, 241,  81, 200, 179, 216, 101, 169,  39,  14, 189, 185,
#        195, 144,  62,  36, 250,   9, 210, 146,  89,  79,  26, 120,  22,
# ...

# %%
SeleccionColumnas=['lpep_pickup_datetime',
                   'lpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

tG8=tG8[SeleccionColumnas]
print(tG8.shape)
tG8.head(1)
# Out:
# (60649, 13)
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-08-01 00:03:21   2023-08-01 00:07:34             7             7
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0           0.81          6.5    1.0      0.5         2.7
#
#    total_amount  payment_type  congestion_surcharge
# 0          11.7           1.0                   0.0

# %%
tG8.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID                0
# DOLocationID                0
# passenger_count          3880
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# total_amount                0
# payment_type             3880
# congestion_surcharge     3880
# dtype: int64

# %%
selccionColumnas8=['passenger_count','payment_type','congestion_surcharge']
tG8_nulos=tG8.dropna(subset=selccionColumnas1)
tG8=tG8_nulos
print(tG8.shape)
tG8.isna().sum()
# Out:
# (56769, 13)
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Septiembre.

# %%
tG9=pd.read_parquet('green_tripdata_2023-09.parquet')
print(tG9.shape)
tG9.head(1)
# Out:
# (65471, 20)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         1  2023-09-01 00:08:04   2023-09-01 00:13:39                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            41            75              1.0            1.1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          7.9    1.0      1.5         0.0           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0          10.4           1.0        1.0
#
#    congestion_surcharge
# 0                   0.0

# %%
print(tG9.columns)
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tG9.columns:
  print(tG9[col].unique())
# Out:
# [1 2]
# ['2023-09-01T00:08:04.000000000' '2023-09-01T00:30:44.000000000'
#  '2023-09-01T00:14:39.000000000' ... '2023-09-30T22:02:00.000000000'
#  '2023-09-30T23:22:00.000000000' '2023-09-30T23:17:00.000000000']
# ['2023-09-01T00:13:39.000000000' '2023-09-01T00:39:30.000000000'
#  '2023-09-01T00:38:30.000000000' ... '2023-09-30T22:38:00.000000000'
#  '2023-09-30T23:38:00.000000000' '2023-09-30T23:42:00.000000000']
# ['N' 'Y' None]
# [ 1.  5.  2.  4.  3.  6. 99. nan]
# [ 41  74  93 112 131 255  92  82 152  75  66 210  95  65 226 130 157 244
#  116 167 265  42 145  80 129 119 247  36 166  40 260 256  43  51  70 173
#  168 222  33  69 159  24   7 216 223 243  97  14  89 136  55 121 196  22
#  189 134 191 181 263  85 236 127 147  60 241   9  83 217  17 185 193 207
#   32  94 182 137 264 102 174  35 195  49  52  25 169  72  37 235  26 179
#   20  10 140 135  61 123 124 237 205 180 138 253  39  91 213  56 126 257
#  132 197 133  18 219 192 225  57 190 146 172 200  47 108 254  76 258 122
# ...

# %%
tG9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65471 entries, 0 to 65470
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               65471 non-null  int32
#  1   lpep_pickup_datetime   65471 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  65471 non-null  datetime64[ns]
#  3   store_and_fwd_flag     60856 non-null  object
#  4   RatecodeID             60856 non-null  float64
#  5   PULocationID           65471 non-null  int32
#  6   DOLocationID           65471 non-null  int32
#  7   passenger_count        60856 non-null  float64
#  8   trip_distance          65471 non-null  float64
#  9   fare_amount            65471 non-null  float64
#  10  extra                  65471 non-null  float64
#  11  mta_tax                65471 non-null  float64
#  12  tip_amount             65471 non-null  float64
#  13  tolls_amount           65471 non-null  float64
# ...

# %%
tG9.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  65471.000000  60856.000000  65471.000000  65471.000000
# mean       1.869118      1.233913     98.814299    139.706863
# std        0.337274      1.331586     58.663890     76.309643
# min        1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000     74.000000     74.000000
# 50%        2.000000      1.000000     75.000000    138.000000
# 75%        2.000000      1.000000    127.000000    220.000000
# max        2.000000     99.000000    265.000000    265.000000
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     60856.000000   65471.000000  65471.000000  65471.000000
# mean          1.305672      24.532310     20.602176      0.881352
# std           0.952041    1419.762707     22.898428      1.365553
# min           0.000000       0.000000   -500.000000     -5.000000
# 25%           1.000000       1.170000     10.000000      0.000000
# ...

# %%
valoresUnicosS9=tG9['store_and_fwd_flag'].unique()
valoresUnicosS9
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1S9=tG9['DOLocationID'].unique()
valoresUnicos1S9
# Out:
# array([ 75, 236, 205,  17,  82, 255, 239, 107, 163, 129,  74, 151,  42,
#        194, 181, 210,  13, 260,  56,  28, 134,  89,  98,  95,  92, 264,
#        198, 208,  68, 233, 157, 133, 116,  49, 244,  43,  69, 265, 202,
#        228,  48, 218,  41, 119, 146, 144,  79, 238,  39, 102, 130, 249,
#        226,  25, 162,  93, 220, 225, 215,  10, 131, 168,  90, 247, 167,
#        145, 166,  37,  36, 223, 256, 237, 138, 186, 137, 132, 170,  45,
#        121, 243,  81, 192, 189,  66,  78,  87, 142, 152,  53, 164, 140,
#        263,  88,  33, 159, 141, 231, 262, 229, 193, 197,  24, 230, 125,
#         14, 143, 112, 171, 139, 127,  55, 126, 135, 136, 196, 211, 213,
#         29,  50, 160, 108,   7,  34, 216, 183, 113,  94, 174,   9,  16,
#        100, 173,  61,  21, 207, 252,  57, 250,  65,  63,  97, 161, 200,
#         86, 217, 258,  70,  83,  77, 195, 177,  40, 188, 241,  35, 165,
#        254, 212, 179, 155, 234, 203, 232,  71, 124, 114,  76,  60,  80,
# ...

# %%
SeleccionColumnas=['lpep_pickup_datetime',
                   'lpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

tG9=tG9[SeleccionColumnas]
print(tG9.shape)
tG9.head(1)
# Out:
# (65471, 13)
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-09-01 00:08:04   2023-09-01 00:13:39            41            75
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0            1.1          7.9    1.0      1.5         0.0
#
#    total_amount  payment_type  congestion_surcharge
# 0          10.4           1.0                   0.0

# %%
tG9.isna().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID                0
# DOLocationID                0
# passenger_count          4615
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# total_amount                0
# payment_type             4615
# congestion_surcharge     4615
# dtype: int64

# %%
selccionColumnas9=['passenger_count','payment_type','congestion_surcharge']
tG9_nulos=tG9.dropna(subset=selccionColumnas9)
tG9=tG9_nulos
print(tG9.shape)
tG9.isna().sum()
# Out:
# (60856, 13)
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Unificación DataFrames

# %%
taxisGreen=pd.concat([tG1,tG2,tG3,tG4,tG5,tG6,tG7,tG8,tG9], ignore_index=True)

# %%
print(taxisGreen.shape)
taxisGreen.head(1)
# Out:
# (551329, 13)
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-01-01 00:26:10   2023-01-01 00:37:11           166           143
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0           2.58         14.9    1.0      0.5        4.03
#
#    total_amount  payment_type  congestion_surcharge
# 0         24.18           1.0                  2.75

# %%
taxisGreen['PULocationID']=taxisGreen['PULocationID'].replace([1],'Newark Airpot')
taxisGreen['PULocationID']=taxisGreen['PULocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
taxisGreen['PULocationID']=taxisGreen['PULocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
taxisGreen['PULocationID']=taxisGreen['PULocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
taxisGreen['PULocationID']=taxisGreen['PULocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
taxisGreen['PULocationID']=taxisGreen['PULocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
taxisGreen['PULocationID']=taxisGreen['PULocationID'].replace([264,265],None)

# %%
taxisGreen['DOLocationID']=taxisGreen['DOLocationID'].replace([1],'Newark Airpot')
taxisGreen['DOLocationID']=taxisGreen['DOLocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
taxisGreen['DOLocationID']=taxisGreen['DOLocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
taxisGreen['DOLocationID']=taxisGreen['DOLocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
taxisGreen['DOLocationID']=taxisGreen['DOLocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
taxisGreen['DOLocationID']=taxisGreen['DOLocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
taxisGreen['DOLocationID']=taxisGreen['DOLocationID'].replace([264,265],None)

# %%
taxisGreen.head()
# Out:
#   lpep_pickup_datetime lpep_dropoff_datetime PULocationID DOLocationID  \
# 0  2023-01-01 00:26:10   2023-01-01 00:37:11    Manhattan    Manhattan
# 1  2023-01-01 00:51:03   2023-01-01 00:57:49    Manhattan    Manhattan
# 2  2023-01-01 00:35:12   2023-01-01 00:41:32       Queens       Queens
# 3  2023-01-01 00:13:14   2023-01-01 00:19:03    Manhattan    Manhattan
# 4  2023-01-01 00:33:04   2023-01-01 00:39:02    Manhattan    Manhattan
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0           2.58         14.9    1.0      0.5        4.03
# 1              1.0           1.81         10.7    1.0      0.5        2.64
# 2              1.0           0.00          7.2    1.0      0.5        1.94
# 3              1.0           1.30          6.5    0.5      1.5        1.70
# 4              1.0           1.10          6.0    0.5      1.5        0.00
#
#    total_amount  payment_type  congestion_surcharge
# ...

# %%
taxisGreen.isna().sum()
# Out:
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID             1726
# DOLocationID             6490
# passenger_count             0
# trip_distance               0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# total_amount                0
# payment_type                0
# congestion_surcharge        0
# dtype: int64

# %%
selccionColumnas10=['PULocationID','DOLocationID']
taxisGreen_nulos=taxisGreen.dropna(subset=selccionColumnas10)
taxisGreen=taxisGreen_nulos
print(taxisGreen.shape)
taxisGreen.isna().sum()
# Out:
# (544451, 13)
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %%
taxisGreen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 544451 entries, 0 to 551328
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   lpep_pickup_datetime   544451 non-null  datetime64[ns]
#  1   lpep_dropoff_datetime  544451 non-null  datetime64[ns]
#  2   PULocationID           544451 non-null  object
#  3   DOLocationID           544451 non-null  object
#  4   passenger_count        544451 non-null  float64
#  5   trip_distance          544451 non-null  float64
#  6   fare_amount            544451 non-null  float64
#  7   extra                  544451 non-null  float64
#  8   mta_tax                544451 non-null  float64
#  9   tip_amount             544451 non-null  float64
#  10  total_amount           544451 non-null  float64
#  11  payment_type           544451 non-null  float64
#  12  congestion_surcharge   544451 non-null  float64
# ...

# %%
taxisGreen = taxisGreen[~taxisGreen['PULocationID'].str.contains('Manhattan',case=False,na=False)]
taxisGreen = taxisGreen[~taxisGreen['PULocationID'].str.contains('Newark Airpot',case=False,na=False)]

# %%
print(taxisGreen.shape)
taxisGreen.info()
# Out:
# (227723, 13)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227723 entries, 2 to 551327
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   lpep_pickup_datetime   227723 non-null  datetime64[ns]
#  1   lpep_dropoff_datetime  227723 non-null  datetime64[ns]
#  2   PULocationID           227723 non-null  object
#  3   DOLocationID           227723 non-null  object
#  4   passenger_count        227723 non-null  float64
#  5   trip_distance          227723 non-null  float64
#  6   fare_amount            227723 non-null  float64
#  7   extra                  227723 non-null  float64
#  8   mta_tax                227723 non-null  float64
#  9   tip_amount             227723 non-null  float64
#  10  total_amount           227723 non-null  float64
#  11  payment_type           227723 non-null  float64
#  12  congestion_surcharge   227723 non-null  float64
# ...

# %%
taxisGreen.to_parquet('/content/drive/My Drive/taxisGreen.parquet01', index=False)

# %%
taxisGreen.to_csv('/content/drive/My Drive/taxisGreen01.csv', index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def analizar_dataframe(taxisGreen):
    nulos_por_columna = taxisGreen.isnull().sum()
    duplicados = taxisGreen.duplicated().sum()
    columnas_numericas = taxisGreen.select_dtypes(include='number')
    plt.figure(figsize=(15,8))
    sns.boxplot(data=columnas_numericas)
    plt.xticks(rotation=45, ha='right')
    plt.show()
    return nulos_por_columna, duplicados

# %%
analizar_dataframe(taxisGreen)
# Out:
# (lpep_pickup_datetime     0
#  lpep_dropoff_datetime    0
#  PULocationID             0
#  DOLocationID             0
#  passenger_count          0
#  trip_distance            0
#  fare_amount              0
#  extra                    0
#  mta_tax                  0
#  tip_amount               0
#  total_amount             0
#  payment_type             0
#  congestion_surcharge     0
#  dtype: int64,
#  0)
