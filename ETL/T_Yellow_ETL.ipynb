# %%
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Mes Enero.

# %%
rutaE1='/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-01.parquet'

# %%
rutaE1
# Out:
# '/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-01.parquet'

# %%
dftY1 = rutaE1
tY1=pd.read_parquet(dftY1)
print(tY1.shape)
tY1.head(1)
# Out:
# (3066766, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          9.3    1.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    1.0          14.3                   2.5          0.0

# %%
print(tY1.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %% [markdown]
# | *Columna* | *Significado* |
# | --- | --- |
# | 	VendorID | Id del Vendedor. |
# | tpep_pickup_datetime | Fecha y hora de la Recogida del Usuario. |
# | tpep_dropoff_datetime | fecha y hora de la Bajada del Usuario. |
# | passenger_count | Reencuento de pasajeros. |
# | trip_distance | Distancia del viaje. |
# | RatecodeID | Id del código de tarifa. |
# | store_and_fwd_flag	 |  Bandera de tienda y Avance. |
# | PULocationID | Id de ubicación PU. |
# | DOLocationID | Id de ubicación DO. |
# | payment_type | Tipo de pago. |
# | fare_amount | Monto de tarifa. |
# | extra | Extra.  |
# | mta_tax | Impuesto mta. |
# | tip_amount | Cantidad de propina. |
# | tolls_amount | Importe de peajes.|
# | improvement_surcharge | Recargo por mejora. |
# | total_amount | Cantidad Total. |
# | congestion_surcharge | Recargo por congestion. |
# | Airport_fee | Tarifa de aeropuerto. |

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tY1.columns:
  print(tY1[col].unique())
# Out:
# [2 1]
# ['2023-01-01T00:32:10.000000000' '2023-01-01T00:55:08.000000000'
#  '2023-01-01T00:25:04.000000000' ... '2023-01-31T23:54:02.000000000'
#  '2023-01-31T23:30:20.000000000' '2023-01-31T23:31:09.000000000']
# ['2023-01-01T00:40:36.000000000' '2023-01-01T01:01:27.000000000'
#  '2023-01-01T00:37:49.000000000' ... '2023-02-01T00:23:17.000000000'
#  '2023-01-31T23:34:38.000000000' '2023-02-01T00:12:33.000000000']
# [ 1.  0.  4.  2.  3.  5.  6.  8.  7.  9. nan]
# [9.700000e-01 1.100000e+00 2.510000e+00 ... 8.554366e+04 3.690550e+03
#  5.204230e+04]
# [ 1.  2.  4. 99.  5.  3.  6. nan]
# ['N' 'Y' None]
# [161  43  48 138 107 239 142 164 141 234  79  33  90 113 237 143 137 132
#  163  68 263 170 233 236 144 229 249 162 224 151 211 148 238 231  13 262
#   75 264 125 186 158 246  50   4  87 114  24 166  41  25 194  74 140 146
#   65 181 255 256  88 232 193 226  97 197  37 189 261 225 244  45  40 116
#   80 209 243  60 265 100  70 188  52   7 159  66  42 174 215 252 136 223
# ...

# %%
tY1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(1)
# ...

# %%
tY1.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  3.066766e+06     2.995023e+06   3.066766e+06  2.995023e+06
# mean   1.730215e+00     1.362532e+00   3.847342e+00  1.497440e+00
# std    4.438480e-01     8.961200e-01   2.495838e+02  6.474767e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.060000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.800000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.330000e+00  1.000000e+00
# max    2.000000e+00     9.000000e+00   2.589281e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  3.066766e+06  3.066766e+06  3.066766e+06  3.066766e+06  3.066766e+06
# mean   1.663980e+02  1.643926e+02  1.194483e+00  1.836707e+01  1.537842e+00
# std    6.424413e+01  6.994368e+01  5.294762e-01  1.780782e+01  1.789592e+00
# ...

# %%
valoresUnicosE1=tY1['store_and_fwd_flag'].unique()
valoresUnicosE1
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1E1=tY1['DOLocationID'].unique()
valoresUnicos1E1
# Out:
# array([141, 237, 238,   7,  79, 137, 143, 200, 236, 107,  68, 264,  33,
#         61, 186,  48, 255, 239, 229, 116, 161, 164,  87, 232, 262,  75,
#         36, 263, 140, 246, 231, 170,  43, 233,   4, 162, 224, 145, 125,
#         24, 265, 163, 114, 225, 211, 158,  42, 151, 261, 148,  13,  50,
#        133, 188, 149,  95, 218, 234, 228, 212, 144, 166, 112,  90, 249,
#         25,  97, 113,  45,  91, 142,  88, 256, 243,  41, 193, 181, 257,
#         94,  80, 195,  10, 194, 167, 127, 248,  89,  74, 223,  47,  40,
#        202, 216, 129, 244,  17, 121,  39,  83,  82, 198, 136,  65, 171,
#        196, 209,  37, 146, 191, 152, 226, 100, 197,  22, 179, 160, 235,
#        168,  29, 260,  35, 189,  92, 130, 165, 132,  63, 252, 119, 185,
#         67, 258,  76,  57, 138, 242, 126, 117,  54, 123, 213, 207,  49,
#         18,  19, 219,  71, 177, 208,   3, 203, 147,   9,  14, 251, 169,
#         52, 153,  53, 106,  70, 122, 254, 205,  62, 155, 247, 220, 124,
# ...

# %%
SeleccionColumnas=['tpep_pickup_datetime',
                   'tpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

'''
 0    VendorID               int32
 1   tpep_pickup_datetime   datetime64[ns]
 2   tpep_dropoff_datetime  datetime64[ns]
 7,3  PULocationID           int32
 8,4   DOLocationID           int32
 3,5   passenger_count        float64
 4,6  trip_distance          float64
 10,7  fare_amount            float64
 11,8  extra                  float64
 12,9  mta_tax                float64
 13,10  tip_amount             float64
 14,11  tolls_amount           float64
 16,12  total_amount           float64
 9,13  payment_type           int64
 17,14  congestion_surcharge   float64

 5   RatecodeID             float64
 6   store_and_fwd_flag     object
 15  improvement_surcharge  float64
 18  Airport_fee
'''

tY1=tY1[SeleccionColumnas]
print(tY1.shape)
tY1.head(1)
# Out:
# (3066766, 13)
#   tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-01-01 00:32:10   2023-01-01 00:40:36           161           141
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0           0.97          9.3    1.0      0.5         0.0
#
#    total_amount  payment_type  congestion_surcharge
# 0          14.3             2                   2.5

# %%
tY1['PULocationID']=tY1['PULocationID'].replace([1],'Newark Airpot')
tY1['PULocationID']=tY1['PULocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY1['PULocationID']=tY1['PULocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY1['PULocationID']=tY1['PULocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY1['PULocationID']=tY1['PULocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY1['PULocationID']=tY1['PULocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY1['PULocationID']=tY1['PULocationID'].replace([264,265],None)

# %%
tY1['DOLocationID']=tY1['DOLocationID'].replace([1],'Newark Airpot')
tY1['DOLocationID']=tY1['DOLocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY1['DOLocationID']=tY1['DOLocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY1['DOLocationID']=tY1['DOLocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY1['DOLocationID']=tY1['DOLocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY1['DOLocationID']=tY1['DOLocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY1['DOLocationID']=tY1['DOLocationID'].replace([264,265],None)

# %%
tY1 = tY1[~tY1['PULocationID'].str.contains('Manhattan',case=False,na=False)]
tY1 = tY1[~tY1['PULocationID'].str.contains('Newark Airpot',case=False,na=False)]

# %%
tY1.isna().sum()
# Out:
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# PULocationID             41763
# DOLocationID             24934
# passenger_count           4693
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# total_amount                 0
# payment_type                 0
# congestion_surcharge      4693
# dtype: int64

# %%
print(tY1.shape)
# Out:
# (350987, 13)

# %%
selccionColumnas1=['PULocationID','DOLocationID','passenger_count','congestion_surcharge']
tY1_nulos=tY1.dropna(subset=selccionColumnas1)
tY1=tY1_nulos
print(tY1.shape)
tY1.isna().sum()
# Out:
# (297034, 13)
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Febrero.

# %%
rutaE2='/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-02.parquet'

# %%
rutaE2
# Out:
# '/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-02.parquet'

# %%
dftY2 = rutaE2
tY2=pd.read_parquet(dftY2)
print(tY2.shape)
tY2.head(1)
# Out:
# (2913955, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.3         1.0                  N           142           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          4.4    3.5      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0           9.4                   2.5          0.0

# %%
print(tY2.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tY2.columns:
  print(tY2[col].unique())
# Out:
# [1 2 6]
# ['2023-02-01T00:32:53.000000000' '2023-02-01T00:35:16.000000000'
#  '2023-02-01T00:29:33.000000000' ... '2023-02-28T23:46:00.000000000'
#  '2023-02-28T23:24:00.000000000' '2023-02-28T23:03:03.000000000']
# ['2023-02-01T00:34:34.000000000' '2023-02-01T00:35:30.000000000'
#  '2023-02-01T01:01:38.000000000' ... '2023-03-01T00:12:00.000000000'
#  '2023-03-01T00:05:00.000000000' '2023-02-28T23:38:00.000000000']
# [ 2.  1.  0.  5.  3.  4.  6.  9.  8.  7. nan]
# [3.00000e-01 0.00000e+00 1.88000e+01 ... 6.35698e+03 1.22919e+04
#  1.29380e+04]
# [ 1.  2.  5.  4.  3. 99.  6. nan]
# ['N' 'Y' None]
# [142  71 132 161 148 137 263  48 114 125 140 249 234 144 236 264 186 230
#  164  79 246 162  68 237 170 141 211  43 138 116 239 158 229 151 159 167
#  262 100 233 238  90 107 219 231  95  22 113  50 232 261  13 163  61  70
#  166  74  69  88  75 168  45 223  24 265 143  97 226  52  42  47  87 244
#  243   4 145 146  33 181 256 188 191 122  10 190  11  26 251  14 260  25
# ...

# %%
tY2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2913955 entries, 0 to 2913954
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
tY2.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  2.913955e+06     2.837138e+06   2.913955e+06  2.837138e+06
# mean   1.731282e+00     1.352847e+00   3.868058e+00  1.514554e+00
# std    4.524952e-01     8.891265e-01   2.684273e+02  6.633395e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.060000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.790000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.300000e+00  1.000000e+00
# max    6.000000e+00     9.000000e+00   3.350043e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  2.913955e+06  2.913955e+06  2.913955e+06  2.913955e+06  2.913955e+06
# mean   1.662570e+02  1.642317e+02  1.182896e+00  1.822038e+01  1.560472e+00
# std    6.413230e+01  6.975406e+01  5.297219e-01  1.749819e+01  1.792708e+00
# ...

# %%
valoresUnicosF2=tY2['store_and_fwd_flag'].unique()
valoresUnicosF2
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1F2=tY2['DOLocationID'].unique()
valoresUnicos1F2
# Out:
# array([163,  71,  26, 145, 236, 244, 141, 243, 211, 249, 107,  42, 226,
#         90,   4, 125, 239, 230,  68,  79, 233,  61,  36,  88, 186, 161,
#         48, 205, 112, 246,  87, 170, 150, 234, 127,  75, 148, 232, 166,
#         80, 238, 140, 264, 263, 260, 164,  41, 223, 167, 173, 189, 100,
#         52, 158, 188, 261, 229, 151,   7,  74,  50, 265, 231,  95, 135,
#        181, 144,  22,  14, 241, 162, 129, 159, 177, 209, 251, 114, 254,
#         13, 178, 216,  89, 113,  98, 143, 137,  28,  70, 262,  17, 237,
#        255,  37,  43, 152, 168, 146, 116, 130, 219,  65,  24,  25,  33,
#         45,  82, 131, 123, 142,  64, 228, 136, 215, 224,  49, 179,  97,
#        126, 124,  62, 118, 155, 160,   3, 133, 134, 102,  76, 225,   8,
#         91,  78, 197,  10,  54, 196, 218,  18,   1, 198, 157, 256, 208,
#         66, 235, 149,  53,  85,  35, 121, 203, 257, 171, 153,  94, 165,
#        220, 132,  39,  67,  63,  83, 139,  56,  16, 217, 212,  23, 185,
# ...

# %%
SeleccionColumnas=['tpep_pickup_datetime',
                   'tpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

'''
 0    VendorID               int32
 1   tpep_pickup_datetime   datetime64[ns]
 2   tpep_dropoff_datetime  datetime64[ns]
 7,3  PULocationID           int32
 8,4   DOLocationID           int32
 3,5   passenger_count        float64
 4,6  trip_distance          float64
 10,7  fare_amount            float64
 11,8  extra                  float64
 12,9  mta_tax                float64
 13,10  tip_amount             float64
 14,11  tolls_amount           float64
 16,12  total_amount           float64
 9,13  payment_type           int64
 17,14  congestion_surcharge   float64

 5   RatecodeID             float64
 6   store_and_fwd_flag     object
 15  improvement_surcharge  float64
 18  Airport_fee
'''

tY2=tY2[SeleccionColumnas]
print(tY2.shape)
tY2.head(1)
# Out:
# (2913955, 13)
#   tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-02-01 00:32:53   2023-02-01 00:34:34           142           163
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              2.0            0.3          4.4    3.5      0.5         0.0
#
#    total_amount  payment_type  congestion_surcharge
# 0           9.4             2                   2.5

# %%
tY2['PULocationID']=tY2['PULocationID'].replace([1],'Newark Airpot')
tY2['PULocationID']=tY2['PULocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY2['PULocationID']=tY2['PULocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY2['PULocationID']=tY2['PULocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY2['PULocationID']=tY2['PULocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY2['PULocationID']=tY2['PULocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY2['PULocationID']=tY2['PULocationID'].replace([264,265],None)

# %%
tY2['DOLocationID']=tY2['DOLocationID'].replace([1],'Newark Airpot')
tY2['DOLocationID']=tY2['DOLocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY2['DOLocationID']=tY2['DOLocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY2['DOLocationID']=tY2['DOLocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY2['DOLocationID']=tY2['DOLocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY2['DOLocationID']=tY2['DOLocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY2['DOLocationID']=tY2['DOLocationID'].replace([264,265],None)

# %%
tY2 = tY2[~tY2['PULocationID'].str.contains('Manhattan',case=False,na=False)]
tY2 = tY2[~tY2['PULocationID'].str.contains('Newark Airpot',case=False,na=False)]

# %%
tY2.isna().sum()
# Out:
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# PULocationID             37554
# DOLocationID             27558
# passenger_count           7755
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# total_amount                 0
# payment_type                 0
# congestion_surcharge      7755
# dtype: int64

# %%
print(tY2.shape)
# Out:
# (309912, 13)

# %%
selccionColumnas2=['PULocationID','DOLocationID','passenger_count','congestion_surcharge']
tY2_nulos=tY2.dropna(subset=selccionColumnas2)
tY2=tY2_nulos
print(tY2.shape)
tY2.isna().sum()
# Out:
# (259094, 13)
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Marzo.

# %%
rutaE3='/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-03.parquet'

# %%
rutaE3
# Out:
# '/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-03.parquet'

# %%
dftY3 = rutaE3
tY3=pd.read_parquet(dftY3)
print(tY3.shape)
tY3.head(1)
# Out:
# (3403766, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-03-01 00:06:43   2023-03-01 00:16:43              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0         1.0                  N           238            42
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          8.6    1.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0          11.1                   0.0          0.0

# %%
print(tY3.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tY3.columns:
  print(tY3[col].unique())
# Out:
# [2 1 6]
# ['2023-03-01T00:06:43.000000000' '2023-03-01T00:08:25.000000000'
#  '2023-03-01T00:15:04.000000000' ... '2023-03-31T23:24:41.000000000'
#  '2023-03-31T23:55:18.000000000' '2023-03-31T23:13:00.000000000']
# ['2023-03-01T00:16:43.000000000' '2023-03-01T00:39:30.000000000'
#  '2023-03-01T00:29:26.000000000' ... '2023-04-01T00:09:45.000000000'
#  '2023-04-01T00:17:00.000000000' '2023-03-31T23:49:39.000000000']
# [ 1.  2.  0.  5.  3.  4.  6.  8.  9.  7. nan]
# [0.000000e+00 1.240000e+01 3.300000e+00 ... 4.221000e+01 5.656111e+04
#  1.179862e+04]
# [ 1.  2. 99.  4.  5.  3.  6. nan]
# ['N' 'Y' None]
# [238 138 140  79 162 170  48 113 239 151 161  43 261 246 107 132 114 230
#   90  76 249 236  68 100 231 229 234  31 141  45 164 137  50 148 163 166
#  263 233 142 237  74 143 159   6 264  70 144 145 125  14  87 262  24 211
#  189 158 146 193  41 186 224 152  75 232 244  88   4 215 209  89 226  97
#  216  13 260   7 212  92 122  36  42  95 177 185 257 179 265  80  25 129
# ...

# %%
tY3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3403766 entries, 0 to 3403765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
tY3.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  3.403766e+06     3.316147e+06   3.403766e+06  3.316147e+06
# mean   1.725320e+00     1.351417e+00   3.903871e+00  1.623961e+00
# std    4.588677e-01     8.861919e-01   1.916866e+02  7.358691e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.050000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.790000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.380000e+00  1.000000e+00
# max    6.000000e+00     9.000000e+00   2.169870e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  3.403766e+06  3.403766e+06  3.403766e+06  3.403766e+06  3.403766e+06
# mean   1.654540e+02  1.641003e+02  1.187310e+00  1.890845e+01  1.629128e+00
# std    6.373958e+01  6.967282e+01  5.334025e-01  1.825637e+01  1.842778e+00
# ...

# %%
valoresUnicosM3=tY3['store_and_fwd_flag'].unique()
valoresUnicosM3
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1M3=tY3['DOLocationID'].unique()
valoresUnicos1M3
# Out:
# array([ 42, 231, 186,  43, 137,  48, 164,  61, 263, 152, 237, 146, 114,
#         50, 162, 234,  68, 239, 230, 255,  40,   7, 258,  10, 244, 100,
#         41, 158, 262, 170, 140,  75,  35,  87, 142, 166,  72, 123, 254,
#        256, 216,  62, 112, 265, 249, 233, 107, 260, 229, 189,  90, 227,
#        246,  47, 113, 179,  33, 236,  74, 232, 143, 141, 116, 151, 145,
#        191, 167,   6, 264, 177, 238,  92,  86,  13,  80, 149, 261, 241,
#         79, 161, 257,  45,  39,  14, 181,  88, 148, 163, 125,  66, 157,
#         17, 159,  76, 129,  83,  89,  95,  49,  97, 106, 243, 138, 224,
#        211,  51, 196, 223, 190, 197, 134,  37, 226,  69, 202, 144,  65,
#         28,  78,  63, 198, 235,  55,   4, 131,  24, 225, 215,  82, 219,
#        165,  25,  91, 247, 150, 222,  22, 193, 209, 155,  36,  70, 175,
#        156, 218, 252, 127,  52, 139,  67, 133,  19, 132, 220, 248,  85,
#        210, 228, 217, 169, 121, 203, 188, 201, 259,  56, 124,  16, 242,
# ...

# %%
SeleccionColumnas=['tpep_pickup_datetime',
                   'tpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

'''
 0    VendorID               int32
 1   tpep_pickup_datetime   datetime64[ns]
 2   tpep_dropoff_datetime  datetime64[ns]
 7,3  PULocationID           int32
 8,4   DOLocationID           int32
 3,5   passenger_count        float64
 4,6  trip_distance          float64
 10,7  fare_amount            float64
 11,8  extra                  float64
 12,9  mta_tax                float64
 13,10  tip_amount             float64
 14,11  tolls_amount           float64
 16,12  total_amount           float64
 9,13  payment_type           int64
 17,14  congestion_surcharge   float64

 5   RatecodeID             float64
 6   store_and_fwd_flag     object
 15  improvement_surcharge  float64
 18  Airport_fee
'''

tY3=tY3[SeleccionColumnas]
print(tY3.shape)
tY3.head(1)
# Out:
# (3403766, 13)
#   tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-03-01 00:06:43   2023-03-01 00:16:43           238            42
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0            0.0          8.6    1.0      0.5         0.0
#
#    total_amount  payment_type  congestion_surcharge
# 0          11.1             2                   0.0

# %%
tY3['PULocationID']=tY3['PULocationID'].replace([1],'Newark Airpot')
tY3['PULocationID']=tY3['PULocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY3['PULocationID']=tY3['PULocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY3['PULocationID']=tY3['PULocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY3['PULocationID']=tY3['PULocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY3['PULocationID']=tY3['PULocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY3['PULocationID']=tY3['PULocationID'].replace([264,265],None)

# %%
tY3['DOLocationID']=tY3['DOLocationID'].replace([1],'Newark Airpot')
tY3['DOLocationID']=tY3['DOLocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY3['DOLocationID']=tY3['DOLocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY3['DOLocationID']=tY3['DOLocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY3['DOLocationID']=tY3['DOLocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY3['DOLocationID']=tY3['DOLocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY3['DOLocationID']=tY3['DOLocationID'].replace([264,265],None)

# %%
tY3 = tY3[~tY3['PULocationID'].str.contains('Manhattan',case=False,na=False)]
tY3 = tY3[~tY3['PULocationID'].str.contains('Newark Airpot',case=False,na=False)]

# %%
tY3.isna().sum()
# Out:
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# PULocationID             34473
# DOLocationID             38097
# passenger_count           8961
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# total_amount                 0
# payment_type                 0
# congestion_surcharge      8961
# dtype: int64

# %%
print(tY3.shape)
# Out:
# (389553, 13)

# %%
selccionColumnas3=['PULocationID','DOLocationID','passenger_count','congestion_surcharge']
tY3_nulos=tY3.dropna(subset=selccionColumnas3)
tY3=tY3_nulos
print(tY3.shape)
tY3.isna().sum()
# Out:
# (339269, 13)
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Abril.

# %%
rutaE4='/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-04.parquet'

# %%
rutaE4
# Out:
# '/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-04.parquet'

# %%
dftY4 = rutaE4
tY4=pd.read_parquet(dftY4)
print(tY4.shape)
tY4.head(1)
# Out:
# (3288250, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-04-01 00:14:49   2023-04-01 00:45:01              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            4.9         1.0                  N            48           223
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         28.9    3.5      0.5         6.0           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0          39.9                   2.5          0.0

# %%
print(tY4.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tY4.columns:
  print(tY4[col].unique())
# Out:
# [1 2 6]
# ['2023-04-01T00:14:49.000000000' '2023-04-01T00:00:24.000000000'
#  '2023-04-01T00:03:50.000000000' ... '2023-04-30T23:13:02.000000000'
#  '2023-04-30T23:25:26.000000000' '2023-04-30T23:04:08.000000000']
# ['2023-04-01T00:45:01.000000000' '2023-04-01T00:56:19.000000000'
#  '2023-04-01T00:14:42.000000000' ... '2023-04-30T23:33:30.000000000'
#  '2023-05-01T00:06:11.000000000' '2023-04-30T23:44:16.000000000']
# [ 2.  1.  6.  0.  3.  5.  4.  7.  8.  9. nan]
# [4.9000000e+00 2.1890000e+01 1.3000000e+00 ... 2.2429380e+04 2.9688142e+05
#  1.6060600e+04]
# [ 1.  2. 99.  5.  3.  4.  6. nan]
# ['N' 'Y' None]
# [ 48 132 148 249 158 163 138 170 230 164  90  68  79 107 211 237 161 234
#  114 144 231 261 140 263 229 264 137 238  88 246  75 239 113  87 186 141
#  100 142  45   7 162 226  70  52 125 233 236 151  74  43   4  97  50 262
#  224 255 232  25 143 124 209 166  41  76  91 181 130  42 116 265 112 157
#   13  65 244  66  33 256 145  80  24 146  10 120 134  54 189 223 168 152
# ...

# %%
tY4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3288250 entries, 0 to 3288249
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
tY4.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  3.288250e+06     3.197560e+06   3.288250e+06  3.197560e+06
# mean   1.731709e+00     1.382820e+00   4.096176e+00  1.598646e+00
# std    4.460662e-01     9.064290e-01   2.553334e+02  7.148677e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.090000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.820000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.490000e+00  1.000000e+00
# max    6.000000e+00     9.000000e+00   2.968814e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  3.288250e+06  3.288250e+06  3.288250e+06  3.288250e+06  3.288250e+06
# mean   1.652098e+02  1.640414e+02  1.193946e+00  1.936058e+01  1.570049e+00
# std    6.418672e+01  7.012333e+01  5.433052e-01  1.883659e+01  1.841736e+00
# ...

# %%
valoresUnicosA4=tY4['store_and_fwd_flag'].unique()
valoresUnicosA4
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1A4=tY1['DOLocationID'].unique()
valoresUnicos1A4
# Out:
# array([141, 237, 238,   7,  79, 137, 143, 200, 236, 107,  68, 264,  33,
#         61, 186,  48, 255, 239, 229, 116, 161, 164,  87, 232, 262,  75,
#         36, 263, 140, 246, 231, 170,  43, 233,   4, 162, 224, 145, 125,
#         24, 265, 163, 114, 225, 211, 158,  42, 151, 261, 148,  13,  50,
#        133, 188, 149,  95, 218, 234, 228, 212, 144, 166, 112,  90, 249,
#         25,  97, 113,  45,  91, 142,  88, 256, 243,  41, 193, 181, 257,
#         94,  80, 195,  10, 194, 167, 127, 248,  89,  74, 223,  47,  40,
#        202, 216, 129, 244,  17, 121,  39,  83,  82, 198, 136,  65, 171,
#        196, 209,  37, 146, 191, 152, 226, 100, 197,  22, 179, 160, 235,
#        168,  29, 260,  35, 189,  92, 130, 165, 132,  63, 252, 119, 185,
#         67, 258,  76,  57, 138, 242, 126, 117,  54, 123, 213, 207,  49,
#         18,  19, 219,  71, 177, 208,   3, 203, 147,   9,  14, 251, 169,
#         52, 153,  53, 106,  70, 122, 254, 205,  62, 155, 247, 220, 124,
# ...

# %%
SeleccionColumnas=['tpep_pickup_datetime',
                   'tpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

'''
 0    VendorID               int32
 1   tpep_pickup_datetime   datetime64[ns]
 2   tpep_dropoff_datetime  datetime64[ns]
 7,3  PULocationID           int32
 8,4   DOLocationID           int32
 3,5   passenger_count        float64
 4,6  trip_distance          float64
 10,7  fare_amount            float64
 11,8  extra                  float64
 12,9  mta_tax                float64
 13,10  tip_amount             float64
 14,11  tolls_amount           float64
 16,12  total_amount           float64
 9,13  payment_type           int64
 17,14  congestion_surcharge   float64

 5   RatecodeID             float64
 6   store_and_fwd_flag     object
 15  improvement_surcharge  float64
 18  Airport_fee
'''

tY4=tY4[SeleccionColumnas]
print(tY4.shape)
tY4.head(1)
# Out:
# (3288250, 13)
#   tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-04-01 00:14:49   2023-04-01 00:45:01            48           223
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              2.0            4.9         28.9    3.5      0.5         6.0
#
#    total_amount  payment_type  congestion_surcharge
# 0          39.9             1                   2.5

# %%
tY4['PULocationID']=tY4['PULocationID'].replace([1],'Newark Airpot')
tY4['PULocationID']=tY4['PULocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY4['PULocationID']=tY4['PULocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY4['PULocationID']=tY4['PULocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY4['PULocationID']=tY4['PULocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY4['PULocationID']=tY4['PULocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY4['PULocationID']=tY4['PULocationID'].replace([264,265],None)

# %%
tY4['DOLocationID']=tY4['DOLocationID'].replace([1],'Newark Airpot')
tY4['DOLocationID']=tY4['DOLocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY4['DOLocationID']=tY4['DOLocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY4['DOLocationID']=tY4['DOLocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY4['DOLocationID']=tY4['DOLocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY4['DOLocationID']=tY4['DOLocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY4['DOLocationID']=tY4['DOLocationID'].replace([264,265],None)

# %%
tY4 = tY4[~tY4['PULocationID'].str.contains('Manhattan',case=False,na=False)]
tY4 = tY4[~tY4['PULocationID'].str.contains('Newark Airpot',case=False,na=False)]

# %%
tY4.isna().sum()
# Out:
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# PULocationID             36145
# DOLocationID             42625
# passenger_count           9304
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# total_amount                 0
# payment_type                 0
# congestion_surcharge      9304
# dtype: int64

# %%
print(tY4.shape)
# Out:
# (389965, 13)

# %%
selccionColumnas4=['PULocationID','DOLocationID','passenger_count','congestion_surcharge']
tY4_nulos=tY4.dropna(subset=selccionColumnas4)
tY4=tY4_nulos
print(tY4.shape)
tY4.isna().sum()
# Out:
# (335503, 13)
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Mayo.

# %%
rutaE5='/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-05.parquet'

# %%
rutaE5
# Out:
# '/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-05.parquet'

# %%
dftY5 = rutaE5
tY5=pd.read_parquet(dftY5)
print(tY5.shape)
tY5.head(1)
# Out:
# (3513649, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-05-01 00:33:13   2023-05-01 00:53:01              0.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            7.8         1.0                  N           138            43
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         33.8   7.75      0.5         8.6           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         51.65                   0.0         1.75

# %%
print(tY5.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tY5.columns:
  print(tY5[col].unique())
# Out:
# [1 2 6]
# ['2023-05-01T00:33:13.000000000' '2023-05-01T00:42:49.000000000'
#  '2023-05-01T00:56:34.000000000' ... '2023-05-31T23:48:26.000000000'
#  '2023-05-31T23:59:36.000000000' '2023-05-31T23:53:00.000000000']
# ['2023-05-01T00:53:01.000000000' '2023-05-01T01:11:18.000000000'
#  '2023-05-01T01:13:39.000000000' ... '2023-06-01T00:28:45.000000000'
#  '2023-06-01T00:13:11.000000000' '2023-05-31T23:56:07.000000000']
# [ 0.  2.  1.  3.  6.  4.  5.  8.  7.  9. nan]
# [7.80000e+00 8.10000e+00 9.10000e+00 ... 4.41800e+01 1.61704e+04
#  1.34498e+04]
# [ 1.  2.  4.  5.  3. 99.  6. nan]
# ['N' 'Y' None]
# [138 161 249 114 132 230 170 107 162 186  70 148  48 246  50  68 237 142
#  100 163 141 146 231 236 229 113 238 234 137 130  90 164 262 144  43 263
#  224 239 233  79 140 211 125 265 264 151  75 158 226  82 152  74  41  25
#  143 129  24   7  39 261 177  87 232   4  97 166 203  93  10  42 215 216
#  145 116  26 106 112 126 247 179 123  56 225 223 209 157  55 260 243 193
# ...

# %%
tY5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3513649 entries, 0 to 3513648
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
tY5.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  3.513649e+06     3.411853e+06   3.513649e+06  3.411853e+06
# mean   1.735567e+00     1.358800e+00   4.345816e+00  1.587358e+00
# std    4.437070e-01     8.796108e-01   2.933984e+02  7.071919e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.090000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.830000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.510000e+00  1.000000e+00
# max    6.000000e+00     9.000000e+00   3.423448e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  3.513649e+06  3.513649e+06  3.513649e+06  3.513649e+06  3.513649e+06
# mean   1.655896e+02  1.645084e+02  1.187269e+00  1.987687e+01  1.616245e+00
# std    6.399413e+01  6.989589e+01  5.427951e-01  1.920861e+01  1.872595e+00
# ...

# %%
valoresUnicosM5=tY5['store_and_fwd_flag'].unique()
valoresUnicosM5
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1M5=tY1['DOLocationID'].unique()
valoresUnicos1M5
# Out:
# array([141, 237, 238,   7,  79, 137, 143, 200, 236, 107,  68, 264,  33,
#         61, 186,  48, 255, 239, 229, 116, 161, 164,  87, 232, 262,  75,
#         36, 263, 140, 246, 231, 170,  43, 233,   4, 162, 224, 145, 125,
#         24, 265, 163, 114, 225, 211, 158,  42, 151, 261, 148,  13,  50,
#        133, 188, 149,  95, 218, 234, 228, 212, 144, 166, 112,  90, 249,
#         25,  97, 113,  45,  91, 142,  88, 256, 243,  41, 193, 181, 257,
#         94,  80, 195,  10, 194, 167, 127, 248,  89,  74, 223,  47,  40,
#        202, 216, 129, 244,  17, 121,  39,  83,  82, 198, 136,  65, 171,
#        196, 209,  37, 146, 191, 152, 226, 100, 197,  22, 179, 160, 235,
#        168,  29, 260,  35, 189,  92, 130, 165, 132,  63, 252, 119, 185,
#         67, 258,  76,  57, 138, 242, 126, 117,  54, 123, 213, 207,  49,
#         18,  19, 219,  71, 177, 208,   3, 203, 147,   9,  14, 251, 169,
#         52, 153,  53, 106,  70, 122, 254, 205,  62, 155, 247, 220, 124,
# ...

# %%
SeleccionColumnas=['tpep_pickup_datetime',
                   'tpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

'''
 0    VendorID               int32
 1   tpep_pickup_datetime   datetime64[ns]
 2   tpep_dropoff_datetime  datetime64[ns]
 7,3  PULocationID           int32
 8,4   DOLocationID           int32
 3,5   passenger_count        float64
 4,6  trip_distance          float64
 10,7  fare_amount            float64
 11,8  extra                  float64
 12,9  mta_tax                float64
 13,10  tip_amount             float64
 14,11  tolls_amount           float64
 16,12  total_amount           float64
 9,13  payment_type           int64
 17,14  congestion_surcharge   float64

 5   RatecodeID             float64
 6   store_and_fwd_flag     object
 15  improvement_surcharge  float64
 18  Airport_fee
'''

tY5=tY5[SeleccionColumnas]
print(tY5.shape)
tY5.head(1)
# Out:
# (3513649, 13)
#   tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-05-01 00:33:13   2023-05-01 00:53:01           138            43
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              0.0            7.8         33.8   7.75      0.5         8.6
#
#    total_amount  payment_type  congestion_surcharge
# 0         51.65             1                   0.0

# %%
tY5['PULocationID']=tY5['PULocationID'].replace([1],'Newark Airpot')
tY5['PULocationID']=tY5['PULocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY5['PULocationID']=tY5['PULocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY5['PULocationID']=tY5['PULocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY5['PULocationID']=tY5['PULocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY5['PULocationID']=tY5['PULocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY5['PULocationID']=tY5['PULocationID'].replace([264,265],None)

# %%
tY5['DOLocationID']=tY5['DOLocationID'].replace([1],'Newark Airpot')
tY5['DOLocationID']=tY5['DOLocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY5['DOLocationID']=tY5['DOLocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY5['DOLocationID']=tY5['DOLocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY5['DOLocationID']=tY5['DOLocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY5['DOLocationID']=tY5['DOLocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY5['DOLocationID']=tY5['DOLocationID'].replace([264,265],None)

# %%
tY5 = tY5[~tY5['PULocationID'].str.contains('Manhattan',case=False,na=False)]
tY5 = tY5[~tY5['PULocationID'].str.contains('Newark Airpot',case=False,na=False)]

# %%
tY5.isna().sum()
# Out:
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# PULocationID             38493
# DOLocationID             44888
# passenger_count          10534
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# total_amount                 0
# payment_type                 0
# congestion_surcharge     10534
# dtype: int64

# %%
print(tY5.shape)
# Out:
# (422613, 13)

# %%
selccionColumnas5=['PULocationID','DOLocationID','passenger_count','congestion_surcharge']
tY5_nulos=tY5.dropna(subset=selccionColumnas5)
tY5=tY5_nulos
print(tY5.shape)
tY5.isna().sum()
# Out:
# (364505, 13)
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Junio.

# %%
rutaE6='/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-06.parquet'

# %%
rutaE6
# Out:
# '/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-06.parquet'

# %%
dftY6 = rutaE6
tY6=pd.read_parquet(dftY6)
print(tY6.shape)
tY6.head(1)
# Out:
# (3307234, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-06-01 00:08:48   2023-06-01 00:29:41              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            3.4         1.0                  N           140           238
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         21.9    3.5      0.5         6.7           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0          33.6                   2.5          0.0

# %%
print(tY6.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tY6.columns:
  print(tY6[col].unique())
# Out:
# [1 2 6]
# ['2023-06-01T00:08:48.000000000' '2023-06-01T00:15:04.000000000'
#  '2023-06-01T00:48:24.000000000' ... '2023-06-30T23:48:50.000000000'
#  '2023-06-30T23:30:21.000000000' '2023-06-30T23:45:00.000000000']
# ['2023-06-01T00:29:41.000000000' '2023-06-01T00:25:18.000000000'
#  '2023-06-01T01:07:07.000000000' ... '2023-07-01T00:32:59.000000000'
#  '2023-07-01T00:10:00.000000000' '2023-06-30T23:51:19.000000000']
# [ 1.  0.  3.  2.  4.  5.  6.  8.  9.  7. nan]
# [3.400000e+00 1.020000e+01 9.830000e+00 ... 3.705844e+04 1.762443e+04
#  2.031400e+04]
# [ 1.  2.  4. 99.  5.  3.  6. nan]
# ['N' 'Y' None]
# [140  50 138 100 137 249 141 246 186 142 234 239 148 132 162 107 230 164
#  256  48  79 229 163 170 232  68  24 263 236 237 114 161  90 144 125 113
#  264 158 211   4  43  13  75 262  87 209 151 143 231 166 238  70 224  45
#   83 112  74 233  41  97 127  65  78 261 247 226   7 202 145 215  88 129
#   67  10  86  42 189 146  25 265 193 116   6  17  37   1 219  38 244 159
# ...

# %%
tY6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3307234 entries, 0 to 3307233
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
tY6.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  3.307234e+06     3.207347e+06   3.307234e+06  3.207347e+06
# mean   1.737262e+00     1.369012e+00   4.368790e+00  1.547159e+00
# std    4.477026e-01     8.959539e-01   2.280398e+02  6.762597e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.080000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.820000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.540000e+00  1.000000e+00
# max    6.000000e+00     9.000000e+00   1.852505e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  3.307234e+06  3.307234e+06  3.307234e+06  3.307234e+06  3.307234e+06
# mean   1.649028e+02  1.638013e+02  1.187126e+00  1.998804e+01  1.620755e+00
# std    6.404389e+01  7.005873e+01  5.478269e-01  2.136687e+02  1.869549e+00
# ...

# %%
valoresUnicosJ6=tY6['store_and_fwd_flag'].unique()
valoresUnicosJ6
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1J6=tY6['DOLocationID'].unique()
valoresUnicos1J6
# Out:
# array([238, 151,  97, 244, 234,  33, 226,  50, 161, 166, 170, 158,  90,
#        125, 229, 228, 241, 137, 230, 145, 100, 141, 112, 164, 169, 233,
#         40,   4, 144, 162,  61, 239,  24, 243, 246,  48, 142,  72, 157,
#        163, 261,  68, 236,  41,   7, 237, 107, 249,  74,  47, 265,  75,
#         66,  27, 152,  13, 264, 255, 232, 186, 224, 140,  79,  17, 231,
#         95, 212, 148,  86, 114,  14, 167, 146, 181, 263, 130,  38, 211,
#         43, 262,  25,  92,  42, 113, 179, 174, 240, 165,  80,  85, 143,
#        198,  45, 216,  28, 159, 180, 129,  87, 260, 102, 196, 116, 182,
#        209,  36,  78, 223, 189, 193,  91,  49, 257,  65, 127, 132,  39,
#        242,   3,  10,  69, 121, 227, 197,  51,  37, 219, 188, 177, 225,
#         62,  70, 256,  60,  89,  52, 153, 191, 235, 248,  35, 202, 168,
#        134, 218, 138, 135,  76,  88,  67, 101,  34, 133, 251,  82, 122,
#        136,  16,  21,   8, 208,   9,  81,  22,  63, 160, 119,  12, 108,
# ...

# %%
SeleccionColumnas=['tpep_pickup_datetime',
                   'tpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

'''
 0    VendorID               int32
 1   tpep_pickup_datetime   datetime64[ns]
 2   tpep_dropoff_datetime  datetime64[ns]
 7,3  PULocationID           int32
 8,4   DOLocationID           int32
 3,5   passenger_count        float64
 4,6  trip_distance          float64
 10,7  fare_amount            float64
 11,8  extra                  float64
 12,9  mta_tax                float64
 13,10  tip_amount             float64
 14,11  tolls_amount           float64
 16,12  total_amount           float64
 9,13  payment_type           int64
 17,14  congestion_surcharge   float64

 5   RatecodeID             float64
 6   store_and_fwd_flag     object
 15  improvement_surcharge  float64
 18  Airport_fee
'''

tY6=tY6[SeleccionColumnas]
print(tY6.shape)
tY6.head(1)
# Out:
# (3307234, 13)
#   tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-06-01 00:08:48   2023-06-01 00:29:41           140           238
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0            3.4         21.9    3.5      0.5         6.7
#
#    total_amount  payment_type  congestion_surcharge
# 0          33.6             1                   2.5

# %%
tY6['PULocationID']=tY6['PULocationID'].replace([1],'Newark Airpot')
tY6['PULocationID']=tY6['PULocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY6['PULocationID']=tY6['PULocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY6['PULocationID']=tY6['PULocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY6['PULocationID']=tY6['PULocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY6['PULocationID']=tY6['PULocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY6['PULocationID']=tY6['PULocationID'].replace([264,265],None)

# %%
tY6['DOLocationID']=tY6['DOLocationID'].replace([1],'Newark Airpot')
tY6['DOLocationID']=tY6['DOLocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY6['DOLocationID']=tY6['DOLocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY6['DOLocationID']=tY6['DOLocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY6['DOLocationID']=tY6['DOLocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY6['DOLocationID']=tY6['DOLocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY6['DOLocationID']=tY6['DOLocationID'].replace([264,265],None)

# %%
tY6 = tY6[~tY6['PULocationID'].str.contains('Manhattan',case=False,na=False)]
tY6 = tY6[~tY6['PULocationID'].str.contains('Newark Airpot',case=False,na=False)]

# %%
tY6.isna().sum()
# Out:
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# PULocationID             35345
# DOLocationID             42446
# passenger_count          12122
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# total_amount                 0
# payment_type                 0
# congestion_surcharge     12122
# dtype: int64

# %%
print(tY6.shape)
# Out:
# (404899, 13)

# %%
selccionColumnas6=['PULocationID','DOLocationID','passenger_count','congestion_surcharge']
tY6_nulos=tY6.dropna(subset=selccionColumnas6)
tY6=tY6_nulos
print(tY6.shape)
tY6.isna().sum()
# Out:
# (347611, 13)
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Julio.

# %%
rutaE7='/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-07.parquet'

# %%
rutaE7
# Out:
# '/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-07.parquet'

# %%
dftY7 = rutaE7
tY7=pd.read_parquet(dftY7)
print(tY7.shape)
tY7.head(1)
# Out:
# (2907108, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-07-01 00:29:59   2023-07-01 00:40:15              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.8         1.0                  N           140           263
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         12.1    3.5      0.5         5.1           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0          22.2                   2.5          0.0

# %%
print(tY7.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tY7.columns:
  print(tY7[col].unique())
# Out:
# [1 2 6]
# ['2023-07-01T00:29:59.000000000' '2023-07-01T00:03:25.000000000'
#  '2023-07-01T00:38:29.000000000' ... '2023-07-31T23:35:12.000000000'
#  '2023-07-31T23:01:00.000000000' '2023-07-31T23:16:57.000000000']
# ['2023-07-01T00:40:15.000000000' '2023-07-01T00:23:44.000000000'
#  '2023-07-01T00:48:53.000000000' ... '2023-07-31T23:18:23.000000000'
#  '2023-07-31T23:51:17.000000000' '2023-07-31T23:46:00.000000000']
# [ 1.  0.  3.  2.  5.  4.  6.  8.  9.  7. nan]
# [1.800000e+00 2.310000e+00 2.360000e+00 ... 3.261924e+04 2.621613e+04
#  6.894083e+04]
# [ 1.  2. 99.  5.  3.  4.  6. nan]
# ['N' 'Y' None]
# [140 163 142  68 161 138 166 186  95 158 170 249 230 137 113  90 246 162
#  144  70 231 107 132 148  50 262 238 264 114 239 143 229  87 141 263  79
#   75 164 236  74  24 226 256  48 125 234 233 237 100  43 167 232 211  52
#   45  88 265  25 151   4  41  40 179 209  97  66 255 116  42 224 202 261
#  152  82  49 145 244 146 129  36 181  13 112  33 189 188   1 127  76 134
# ...

# %%
tY7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907108 entries, 0 to 2907107
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
tY7.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  2.907108e+06     2.822022e+06   2.907108e+06  2.822022e+06
# mean   1.746044e+00     1.401971e+00   4.489381e+00  1.612139e+00
# std    4.409572e-01     9.212167e-01   2.578832e+02  7.188087e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.060000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.810000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.580000e+00  1.000000e+00
# max    6.000000e+00     9.000000e+00   1.919450e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  2.907108e+06  2.907108e+06  2.907108e+06  2.907108e+06  2.907108e+06
# mean   1.632285e+02  1.622275e+02  1.209945e+00  1.970319e+01  1.542589e+00
# std    6.371834e+01  7.005392e+01  5.673058e-01  1.983865e+01  1.849668e+00
# ...

# %%
valoresUnicosJ7=tY7['store_and_fwd_flag'].unique()
valoresUnicosJ7
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1J7=tY7['DOLocationID'].unique()
valoresUnicos1J7
# Out:
# array([263, 163, 262,  24, 107, 186, 230, 244,  70,   7, 236, 142,  68,
#        249, 161, 158, 234, 145,  90, 229,  48, 144, 246, 233, 126,  79,
#        143, 137, 125,  12,   4,  62,  41, 264, 239, 164, 141,  87, 151,
#        114,  97, 179,  82, 147, 254, 162, 123, 100, 168,  74, 127,  65,
#        129, 256, 148, 211,  49, 257, 231, 166,  33,  75, 255, 112,  50,
#        140,  13, 113, 248, 152, 167, 237, 261, 232,  63, 238, 228, 235,
#        134,  42,  92,  66,  45, 201,  22, 170, 226, 218, 146, 188, 265,
#         10, 223,  89,  39, 243,  61,  19,  25, 116,  28,  95, 189, 227,
#         36,  67, 209, 224, 133, 177,  83, 190, 219, 173,  80, 131, 198,
#         52, 181,  76,  72, 213, 202,  16,  88, 101,  17,  40, 225,  69,
#        182, 247, 136,  37, 197,  43, 130,   1,  71, 124, 138,  73,  56,
#        106, 132, 212,  47,  55, 216, 260, 119, 196, 160,  11,  14, 175,
#         29,   9, 121, 195, 205, 149,  54, 139, 210, 215, 174, 204, 155,
# ...

# %%
SeleccionColumnas=['tpep_pickup_datetime',
                   'tpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

'''
 0    VendorID               int32
 1   tpep_pickup_datetime   datetime64[ns]
 2   tpep_dropoff_datetime  datetime64[ns]
 7,3  PULocationID           int32
 8,4   DOLocationID           int32
 3,5   passenger_count        float64
 4,6  trip_distance          float64
 10,7  fare_amount            float64
 11,8  extra                  float64
 12,9  mta_tax                float64
 13,10  tip_amount             float64
 14,11  tolls_amount           float64
 16,12  total_amount           float64
 9,13  payment_type           int64
 17,14  congestion_surcharge   float64

 5   RatecodeID             float64
 6   store_and_fwd_flag     object
 15  improvement_surcharge  float64
 18  Airport_fee
'''

tY7=tY7[SeleccionColumnas]
print(tY7.shape)
tY7.head(1)
# Out:
# (2907108, 13)
#   tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-07-01 00:29:59   2023-07-01 00:40:15           140           263
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0            1.8         12.1    3.5      0.5         5.1
#
#    total_amount  payment_type  congestion_surcharge
# 0          22.2             1                   2.5

# %%
tY7['PULocationID']=tY7['PULocationID'].replace([1],'Newark Airpot')
tY7['PULocationID']=tY7['PULocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY7['PULocationID']=tY7['PULocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY7['PULocationID']=tY7['PULocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY7['PULocationID']=tY7['PULocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY7['PULocationID']=tY7['PULocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY7['PULocationID']=tY7['PULocationID'].replace([264,265],None)

# %%
tY7['DOLocationID']=tY7['DOLocationID'].replace([1],'Newark Airpot')
tY7['DOLocationID']=tY7['DOLocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY7['DOLocationID']=tY7['DOLocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY7['DOLocationID']=tY7['DOLocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY7['DOLocationID']=tY7['DOLocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY7['DOLocationID']=tY7['DOLocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY7['DOLocationID']=tY7['DOLocationID'].replace([264,265],None)

# %%
tY7 = tY7[~tY7['PULocationID'].str.contains('Manhattan',case=False,na=False)]
tY7 = tY7[~tY7['PULocationID'].str.contains('Newark Airpot',case=False,na=False)]

# %%
tY7.isna().sum()
# Out:
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# PULocationID             31111
# DOLocationID             39207
# passenger_count           9632
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# total_amount                 0
# payment_type                 0
# congestion_surcharge      9632
# dtype: int64

# %%
print(tY7.shape)
# Out:
# (373084, 13)

# %%
selccionColumnas7=['PULocationID','DOLocationID','passenger_count','congestion_surcharge']
tY7_nulos=tY7.dropna(subset=selccionColumnas7)
tY7=tY7_nulos
print(tY7.shape)
tY7.isna().sum()
# Out:
# (321704, 13)
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Agosto.

# %%
rutaE8='/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-08.parquet'

# %%
rutaE8
# Out:
# '/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-08.parquet'

# %%
dftY8 = rutaE8
tY8=pd.read_parquet(dftY8)
print(tY8.shape)
tY8.head(1)
# Out:
# (2824209, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-08-01 00:26:44   2023-08-01 00:45:25              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            4.3         1.0                  N           263            90
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         21.9    3.5      0.5        5.35           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         32.25                   2.5          0.0

# %%
print(tY8.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tY8.columns:
  print(tY8[col].unique())
# Out:
# [1 2 6]
# ['2023-08-01T00:26:44.000000000' '2023-08-01T00:55:42.000000000'
#  '2023-08-01T00:32:04.000000000' ... '2023-08-31T23:16:03.000000000'
#  '2023-08-31T23:15:42.000000000' '2023-08-31T23:32:45.000000000']
# ['2023-08-01T00:45:25.000000000' '2023-08-01T01:00:53.000000000'
#  '2023-08-01T01:09:03.000000000' ... '2023-08-31T23:56:46.000000000'
#  '2023-09-01T00:13:01.000000000' '2023-09-01T00:04:36.000000000']
# [ 1.  2.  5.  3.  4.  6.  0.  8.  9.  7. nan]
# [4.3000000e+00 0.0000000e+00 2.0610000e+01 ... 1.1957684e+05 4.3670000e+01
#  4.7470000e+01]
# [ 1.  2.  5.  4. 99.  3.  6. nan]
# ['N' 'Y' None]
# [263 132 138 140 143  50 142 230  87 249  68 162 233  48 246 151 236 229
#   79 148   4 211 141 161 163 234 114 100 164  70 186  75 238 144 264  90
#  166 107 237  43 170 231 158 113 226 256 239   6  24  45 137 255 181  74
#  265 146  12 244  88 119 168 261  33  10 209  97 145 129  13  41 125  37
#   65  49  42  47 124 116   7 232 260 224 180 262  93  63 223  17  25  29
# ...

# %%
tY8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2824209 entries, 0 to 2824208
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
tY8.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  2.824209e+06     2.736323e+06   2.824209e+06  2.736323e+06
# mean   1.747010e+00     1.386975e+00   4.782808e+00  1.806066e+00
# std    4.397541e-01     9.043021e-01   3.742596e+02  8.389951e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.070000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.830000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.610000e+00  1.000000e+00
# max    6.000000e+00     9.000000e+00   3.457294e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  2.824209e+06  2.824209e+06  2.824209e+06  2.824209e+06  2.824209e+06
# mean   1.632055e+02  1.621792e+02  1.211884e+00  1.971853e+01  1.578949e+00
# std    6.361660e+01  6.994845e+01  5.748265e-01  1.980765e+01  1.880450e+00
# ...

# %%
valoresUnicosA8=tY8['store_and_fwd_flag'].unique()
valoresUnicosA8
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1J8=tY8['DOLocationID'].unique()
valoresUnicos1J8
# Out:
# array([ 90, 132,  13, 254, 143, 142,  41, 229,  37, 177, 162, 265,  63,
#        256, 263, 171,  50, 148, 137, 228, 141, 230, 113,  48,  74, 152,
#        239, 188,  79,  14, 107, 211, 234,   4, 144,  87,  36, 129,  75,
#        163, 198, 126, 249, 100, 236, 161, 231, 158, 164, 151, 216,  68,
#        114, 181,  20,  43, 116, 262, 219, 170, 147, 238,   7,  17, 159,
#        225, 130, 264,  49, 102, 258, 209, 131, 212, 237,  42, 233,  39,
#         88,  80, 227, 197,  52, 186, 261,  33, 175,  21, 246, 112, 243,
#         70,  10, 224, 139,  61, 140, 182, 232,  92, 145,  95, 146, 215,
#         24, 223,   6,  25,  28,  55, 255, 178, 257,  77, 160,  47, 125,
#        166,  51,  60, 248, 244, 259, 202,  82,  45,  65, 196, 247, 205,
#         91,  97, 222, 153, 241, 127, 168, 157, 179,  71,  83, 167,  76,
#         85,  86, 134,  89,  26, 213, 165, 226,  78, 250,  73, 192, 119,
#         35,  66,  19,  81, 121,   9,  40,  56, 174, 191, 138, 120,  23,
# ...

# %%
SeleccionColumnas=['tpep_pickup_datetime',
                   'tpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

'''
 0    VendorID               int32
 1   tpep_pickup_datetime   datetime64[ns]
 2   tpep_dropoff_datetime  datetime64[ns]
 7,3  PULocationID           int32
 8,4   DOLocationID           int32
 3,5   passenger_count        float64
 4,6  trip_distance          float64
 10,7  fare_amount            float64
 11,8  extra                  float64
 12,9  mta_tax                float64
 13,10  tip_amount             float64
 14,11  tolls_amount           float64
 16,12  total_amount           float64
 9,13  payment_type           int64
 17,14  congestion_surcharge   float64

 5   RatecodeID             float64
 6   store_and_fwd_flag     object
 15  improvement_surcharge  float64
 18  Airport_fee
'''

tY8=tY8[SeleccionColumnas]
print(tY8.shape)
tY8.head(1)
# Out:
# (2824209, 13)
#   tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-08-01 00:26:44   2023-08-01 00:45:25           263            90
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0            4.3         21.9    3.5      0.5        5.35
#
#    total_amount  payment_type  congestion_surcharge
# 0         32.25             1                   2.5

# %%
tY8['PULocationID']=tY8['PULocationID'].replace([1],'Newark Airpot')
tY8['PULocationID']=tY8['PULocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY8['PULocationID']=tY8['PULocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY8['PULocationID']=tY8['PULocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY8['PULocationID']=tY8['PULocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY8['PULocationID']=tY8['PULocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY8['PULocationID']=tY8['PULocationID'].replace([264,265],None)

# %%
tY8['DOLocationID']=tY8['DOLocationID'].replace([1],'Newark Airpot')
tY8['DOLocationID']=tY8['DOLocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY8['DOLocationID']=tY8['DOLocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY8['DOLocationID']=tY8['DOLocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY8['DOLocationID']=tY8['DOLocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY8['DOLocationID']=tY8['DOLocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY8['DOLocationID']=tY8['DOLocationID'].replace([264,265],None)

# %%
tY8 = tY8[~tY8['PULocationID'].str.contains('Manhattan',case=False,na=False)]
tY8 = tY8[~tY8['PULocationID'].str.contains('Newark Airpot',case=False,na=False)]

# %%
tY8.isna().sum()
# Out:
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# PULocationID             28339
# DOLocationID             36464
# passenger_count          10056
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# total_amount                 0
# payment_type                 0
# congestion_surcharge     10056
# dtype: int64

# %%
print(tY8.shape)
# Out:
# (372407, 13)

# %%
selccionColumnas8=['PULocationID','DOLocationID','passenger_count','congestion_surcharge']
tY8_nulos=tY8.dropna(subset=selccionColumnas8)
tY8=tY8_nulos
print(tY8.shape)
tY8.isna().sum()
# Out:
# (323374, 13)
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# ## Mes Septiembre.

# %%
rutaE9='/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-09.parquet'

# %%
rutaE9
# Out:
# '/content/drive/MyDrive/PIF/data/yellow_tripdata_2023-09.parquet'

# %%
dftY9 = rutaE9
tY9=pd.read_parquet(dftY9)
print(tY9.shape)
tY9.head(1)
# Out:
# (2846722, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-09-01 00:15:37   2023-09-01 00:20:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.8         1.0                  N           163           230
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          6.5    3.5      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0          11.5                   2.5          0.0

# %%
print(tY9.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
# Analizamos los distintos tipos de datos por columna.
for col in tY9.columns:
  print(tY9[col].unique())
# Out:
# [1 2 6]
# ['2023-09-01T00:15:37.000000000' '2023-09-01T00:18:40.000000000'
#  '2023-09-01T00:35:01.000000000' ... '2023-09-30T23:53:30.000000000'
#  '2023-09-30T23:29:31.000000000' '2023-09-30T23:55:33.000000000']
# ['2023-09-01T00:20:21.000000000' '2023-09-01T00:30:28.000000000'
#  '2023-09-01T00:39:04.000000000' ... '2023-09-30T23:54:57.000000000'
#  '2023-10-01T00:15:18.000000000' '2023-10-01T00:03:47.000000000']
# [ 1.  2.  3.  0.  5.  4.  6.  8.  9.  7. nan]
# [8.000000e-01 2.340000e+00 1.620000e+00 ... 9.333710e+03 4.284000e+01
#  3.151619e+04]
# [ 1.  2.  5. 99.  4.  3.  6. nan]
# ['N' 'Y' None]
# [163 236 162 141 138  93 140  45 238 132 230 234  74 161  43 142  79  68
#  158 114  90 164 186 125 265 229 232 249  48 113 170 263 246 211 237 148
#  233 226  17 219 207 107 100  52 231  35 137 144  98  87  65 166  75  13
#  239   4   7 209  88 264 253  70 261 185 168  50 145 262 112 143 152 190
#   25  80 254 179  92 151 241  37 129  62 181  24  97  42 225  41 126 224
# ...

# %%
tY9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2846722 entries, 0 to 2846721
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
tY9.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  2.846722e+06     2.706497e+06   2.846722e+06  2.706497e+06
# mean   1.744071e+00     1.356400e+00   4.274268e+00  1.698767e+00
# std    4.431878e-01     8.780651e-01   2.394240e+02  7.749989e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.000000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.750000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.450000e+00  1.000000e+00
# max    6.000000e+00     9.000000e+00   2.658694e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  2.846722e+06  2.846722e+06  2.846722e+06  2.846722e+06  2.846722e+06
# mean   1.649228e+02  1.639220e+02  1.164290e+00  2.067111e+01  1.522874e+00
# std    6.421352e+01  6.999599e+01  5.742757e-01  1.418298e+02  6.210537e+00
# ...

# %%
valoresUnicosS9=tY9['store_and_fwd_flag'].unique()
valoresUnicosS9
# Out:
# array(['N', 'Y', None], dtype=object)

# %%
valoresUnicos1S9=tY9['DOLocationID'].unique()
valoresUnicos1S9
# Out:
# array([230, 233, 236, 229,  75, 255,   7, 164, 140, 138, 170, 186, 189,
#        161,  90,  42,  79, 163,  48, 234, 114,  68, 181,  88, 224, 209,
#        263, 265, 239, 141, 107, 246, 247, 143, 248,  74,  39, 158, 142,
#         37, 100, 237, 232, 211, 200, 148, 151,  89, 249, 129, 219,  10,
#         50, 261, 231,  41,  13, 162,  40, 145, 188, 144,  52,  98, 262,
#        179,  97, 137, 112, 238, 195,  87, 264,   3,  45, 256, 243,  36,
#        260, 166, 157, 216, 225, 253, 244, 125,  14,  49, 165,  86, 203,
#        116, 111,  24,  69, 127, 113,  61,  91, 252, 223,   4, 185, 190,
#        208,  92, 198,  33,  94,  56, 228, 133,  63, 131,  95,  65, 226,
#        117, 193, 152, 132,  25,  16, 177,  93,  21,  34,  62,  80, 254,
#         73, 183,  22,  66, 235, 227, 196, 146,  76,  17, 197, 241,  54,
#        180, 257,  15,  43, 167, 130, 139, 210,  85, 202, 155, 126, 182,
#         71,  67,  18,  32, 119, 258, 168, 106, 101,  82, 192,   9,  83,
# ...

# %%
SeleccionColumnas=['tpep_pickup_datetime',
                   'tpep_dropoff_datetime',
                   'PULocationID',
                   'DOLocationID',
                   'passenger_count',
                   'trip_distance',
                   'fare_amount',
                   'extra',
                   'mta_tax',
                   'tip_amount',
                   'total_amount',
                   'payment_type',
                   'congestion_surcharge']

'''
 0    VendorID               int32
 1   tpep_pickup_datetime   datetime64[ns]
 2   tpep_dropoff_datetime  datetime64[ns]
 7,3  PULocationID           int32
 8,4   DOLocationID           int32
 3,5   passenger_count        float64
 4,6  trip_distance          float64
 10,7  fare_amount            float64
 11,8  extra                  float64
 12,9  mta_tax                float64
 13,10  tip_amount             float64
 14,11  tolls_amount           float64
 16,12  total_amount           float64
 9,13  payment_type           int64
 17,14  congestion_surcharge   float64

 5   RatecodeID             float64
 6   store_and_fwd_flag     object
 15  improvement_surcharge  float64
 18  Airport_fee
'''

tY9=tY9[SeleccionColumnas]
print(tY9.shape)
tY9.head(1)
# Out:
# (2846722, 13)
#   tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2023-09-01 00:15:37   2023-09-01 00:20:21           163           230
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              1.0            0.8          6.5    3.5      0.5         0.0
#
#    total_amount  payment_type  congestion_surcharge
# 0          11.5             2                   2.5

# %%
tY9['PULocationID']=tY9['PULocationID'].replace([1],'Newark Airpot')
tY9['PULocationID']=tY9['PULocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY9['PULocationID']=tY9['PULocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY9['PULocationID']=tY9['PULocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY9['PULocationID']=tY9['PULocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY9['PULocationID']=tY9['PULocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY9['PULocationID']=tY9['PULocationID'].replace([264,265],None)

# %%
tY9['DOLocationID']=tY9['DOLocationID'].replace([1],'Newark Airpot')
tY9['DOLocationID']=tY9['DOLocationID'].replace([4,12,13,24,41,42,43,45,48,50,68,74,75,79,87,88,90,100,103,104,105,107,113,114,116,120,125,127,128,137,140,141,142,143,144,148,151,152,153,158,161,162,163,164,166,170,186,194,202,209,211,224,229,230,231,232,233,234,236,237,238,239,243,244,246,249,261,262,263],'Manhattan')
tY9['DOLocationID']=tY9['DOLocationID'].replace([2,7,8,9,10,15,16,19,27,28,30,38,53,56,57,64,70,73,82,83,86,92,93,95,96,98,101,102,117,121,122,124,129,130,131,132,134,135,138,139,145,146,157,160,171,173,175,179,180,191,192,193,196,197,198,201,203,205,207,215,216,218,219,223,226,252,253,258,260],'Queens')
tY9['DOLocationID']=tY9['DOLocationID'].replace([3,18,20,31,32,46,47,51,58,59,60,69,78,81,94,119,126,136,147,159,167,168,169,174,182,183,184,185,199,200,208,212,213,220,235,240,241,242,247,248,250,254,259],'Bronx')
tY9['DOLocationID']=tY9['DOLocationID'].replace([5,6,23,44,84,99,109,110,115,118,156,172,176,187,204,206,214,221,245,251],'Staten Island')
tY9['DOLocationID']=tY9['DOLocationID'].replace([11,14,17,21,22,25,26,29,33,34,35,36,37,39,40,49,52,54,55,61,62,63,65,66,67,71,72,76,77,80,85,89,91,97,106,108,111,112,123,133,149,150,154,155,165,177,178,181,188,189,190,195,210,217,222,225,227,228,255,256,257],'Brooklyn')
tY9['DOLocationID']=tY9['DOLocationID'].replace([264,265],None)

# %%
tY9 = tY9[~tY9['PULocationID'].str.contains('Manhattan',case=False,na=False)]
tY9 = tY9[~tY9['PULocationID'].str.contains('Newark Airpot',case=False,na=False)]

# %%
tY9.isna().sum()
# Out:
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# PULocationID             29029
# DOLocationID             34872
# passenger_count          13340
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# total_amount                 0
# payment_type                 0
# congestion_surcharge     13340
# dtype: int64

# %%
print(tY9.shape)
# Out:
# (356177, 13)

# %%
selccionColumnas9=['PULocationID','DOLocationID','passenger_count','congestion_surcharge']
tY9_nulos=tY9.dropna(subset=selccionColumnas9)
tY9=tY9_nulos
print(tY9.shape)
tY9.isna().sum()
# Out:
# (305201, 13)
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# total_amount             0
# payment_type             0
# congestion_surcharge     0
# dtype: int64

# %%
taxisYellowT1=pd.concat([tY1,tY2,tY3], ignore_index=True)

# %%
taxisYellowT1.to_csv('/content/drive/My Drive/taxisYellowTrimestre01.csv', index=False)

# %%
taxisYellowT1.to_parquet('/content/drive/My Drive/taxisYellowTrimeste01.parquet', index=False)

# %%
taxisYellowT2=pd.concat([tY4,tY5,tY6], ignore_index=True)

# %%
taxisYellowT2.to_csv('/content/drive/My Drive/taxisYellowTrimestre02.csv', index=False)

# %%
taxisYellowT2.to_parquet('/content/drive/My Drive/taxisYellowTrimeste02.parquet', index=False)

# %%
taxisYellowT3=pd.concat([tY7,tY8,tY9], ignore_index=True)

# %%
taxisYellowT3.to_csv('/content/drive/My Drive/taxisYellowTrimestre03.csv', index=False)

# %%
taxisYellowT3.to_parquet('/content/drive/My Drive/taxisYellowTrimeste03.parquet', index=False)

# %%
taxisYellow=pd.concat([tY1,tY2,tY3,tY4,tY5,tY6,tY7,tY8,tY9], ignore_index=True)

# %%
taxisYellow.to_parquet('/content/drive/My Drive/taxisYellow01.parquet', index=False)

# %%
taxisYellow.to_csv('/content/drive/My Drive/taxisYellow01.csv', index=False)
