# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta= '/content/drive/MyDrive/taxis_clean/'

# %%
import pandas as pd

# %%
septiembre  = pd.read_parquet(ruta + 'septiembre.parquet')
agosto = pd.read_parquet(ruta + 'agosto.parquet')
julio = pd.read_parquet(ruta + 'julio.parquet')
junio = pd.read_parquet(ruta + 'junio.parquet')
abril = pd.read_parquet(ruta + 'abril.parquet')
mayo = pd.read_parquet(ruta + 'mayo.parquet')

# %%
mayo_ml_3 = mayo.drop(columns = ['vendorid', 'tpep_pickup_datetime',
       'passenger_count', 'ratecodeid', 'store_and_fwd_flag',
       'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tolls_amount', 'improvement_surcharge',
       'tip_amount', 'congestion_surcharge', 'airport_fee', 'total_amount',
        'pickup_borough', 'pickup_zone','tpep_dropoff_datetime',
       'dropoff_borough', 'dropoff_zone'])

junio_ml_3 = junio.drop(columns = ['vendorid', 'tpep_pickup_datetime',
       'passenger_count', 'ratecodeid', 'store_and_fwd_flag',
       'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tolls_amount', 'improvement_surcharge','tpep_dropoff_datetime',
       'tip_amount', 'congestion_surcharge', 'airport_fee', 'total_amount',
        'pickup_borough', 'pickup_zone',
       'dropoff_borough', 'dropoff_zone'])

julio_ml_3 = julio.drop(columns = ['vendorid', 'tpep_pickup_datetime',
       'passenger_count', 'ratecodeid', 'store_and_fwd_flag',
       'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tolls_amount', 'improvement_surcharge','tpep_dropoff_datetime',
       'tip_amount', 'congestion_surcharge', 'airport_fee', 'total_amount',
        'pickup_borough', 'pickup_zone',
       'dropoff_borough', 'dropoff_zone'])

agosto_ml_3 = agosto.drop(columns = ['vendorid', 'tpep_pickup_datetime',
       'passenger_count', 'ratecodeid', 'store_and_fwd_flag',
       'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tolls_amount', 'improvement_surcharge','tpep_dropoff_datetime',
       'tip_amount', 'congestion_surcharge', 'airport_fee', 'total_amount',
        'pickup_borough', 'pickup_zone',
       'dropoff_borough', 'dropoff_zone'])

septiembre_ml_3 = septiembre.drop(columns = ['vendorid', 'tpep_pickup_datetime',
       'passenger_count', 'ratecodeid', 'store_and_fwd_flag',
       'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tolls_amount', 'improvement_surcharge',
       'tip_amount', 'congestion_surcharge', 'airport_fee', 'total_amount',
        'pickup_borough', 'pickup_zone', 'tpep_dropoff_datetime',
       'dropoff_borough', 'dropoff_zone'])

# %%
septiembre_ml_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2438472 entries, 0 to 2438471
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   trip_distance     float64
#  1   duracion          float64
#  2   hora_del_dia      int64
#  3   dia_de_la_semana  int64
# dtypes: float64(2), int64(2)
# memory usage: 93.0 MB

# %%
agosto_ml_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2413401 entries, 0 to 2413400
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   trip_distance     float64
#  1   duracion          float64
#  2   hora_del_dia      int64
#  3   dia_de_la_semana  int64
# dtypes: float64(2), int64(2)
# memory usage: 92.1 MB

# %%
julio_ml_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2490675 entries, 0 to 2490674
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   trip_distance     float64
#  1   duracion          float64
#  2   hora_del_dia      int64
#  3   dia_de_la_semana  int64
# dtypes: float64(2), int64(2)
# memory usage: 95.0 MB

# %%
junio_ml_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2834507 entries, 0 to 2834506
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   trip_distance     float64
#  1   duracion          float64
#  2   hora_del_dia      int64
#  3   dia_de_la_semana  int64
# dtypes: float64(2), int64(2)
# memory usage: 108.1 MB

# %%
mayo_ml_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3013972 entries, 0 to 3013971
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   trip_distance     float64
#  1   duracion          float64
#  2   hora_del_dia      int64
#  3   dia_de_la_semana  int64
# dtypes: float64(2), int64(2)
# memory usage: 115.0 MB

# %%
viajes_taxis = pd.concat([septiembre_ml_3, agosto_ml_3, julio_ml_3, junio_ml_3, mayo_ml_3])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import joblib
import matplotlib.pyplot as plt

# Cargar el DataFrame
# Asegúrate de tener 'viajes_taxis' cargado con los datos relevantes

# Seleccionar características y variable objetivo
features_regresion = ['trip_distance', 'hora_del_dia', 'dia_de_la_semana']
target_regresion = 'duracion'

# Dividir datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(viajes_taxis[features_regresion], viajes_taxis[target_regresion], test_size=0.1, random_state=42)

# Modelos
modelos = {
    #'RandomForest': RandomForestRegressor(n_estimators=120, random_state=42, max_depth = 12),
    'GradientBoosting': GradientBoostingRegressor(n_estimators=200, random_state=42, learning_rate = 0.05,  ),
    # 'AdaBoost': AdaBoostRegressor(n_estimators=100, random_state=42),
    # 'KNeighbors': KNeighborsRegressor(n_neighbors=3)
}

# Entrenar y guardar cada modelo
for nombre, modelo in modelos.items():
    modelo.fit(X_train, y_train)
    joblib.dump(modelo, f'{nombre}_model.joblib')

    # Hacer predicciones
    y_pred = modelo.predict(X_test)

    # Calcular el Mean Squared Error (MSE)
    mse = mean_squared_error(y_test, y_pred)
    print(f'{nombre} Mean Squared Error: {mse}')

    # Calcular el Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_test, y_pred)
    print(f'{nombre} Mean Absolute Error: {mae}')

    y_train_pred = modelo.predict(X_train)

    # Calcular el Mean Squared Error (MSE)
    mse_train = mean_squared_error(y_train, y_train_pred)
    print(f'{nombre} Mean Squared Error (Train): {mse_train}')

    # Calcular el Mean Absolute Error (MAE)
    mae_train = mean_absolute_error(y_train, y_train_pred)
    print(f'{nombre} Mean Absolute Error (Train): {mae_train}')

    # Crear una serie de números para el eje x (1 a 200)
    n_valores = 150
    eje_x = range(1, n_valores + 1)

    # Obtener solo los primeros 200 valores
    y_test_subset = y_test[:n_valores]
    y_pred_subset = y_pred[:n_valores]

    # Graficar las líneas para y_test y y_pred
    plt.figure(figsize=(10, 6))
    plt.plot(eje_x, y_test_subset, label='Valores Reales', marker='o', linestyle='-', color='blue')
    plt.plot(eje_x, y_pred_subset, label='Valores Predichos', marker='o', linestyle='-', color='red')

    # Configurar el gráfico
    plt.title(f'Comparación entre Valores Reales y Valores Predichos ({nombre})')
    plt.xlabel('Número de Valores')
    plt.ylabel('Valores')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'plot_{nombre}.png')
    plt.show()
# Out:
# GradientBoosting Mean Squared Error: 1500.0234988512639
# GradientBoosting Mean Absolute Error: 4.934676361262963
# GradientBoosting Mean Squared Error (Train): 1466.1981747161583
# GradientBoosting Mean Absolute Error (Train): 4.908522476593986

# %%
# Calcular el error entre las predicciones y los valores reales
error = y_test - y_pred

# Crear un histograma del error con límites en el eje x entre 0 y 100
plt.figure(figsize=(10, 6))
plt.hist(error, bins=30, range=(-30, 30), edgecolor='black', alpha=0.7)
plt.title('Distribución del Error prediccion de duracion del viaje')
plt.xlabel('Error')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()
